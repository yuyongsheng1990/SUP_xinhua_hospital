# %%
# _*_ coding: utf-8 _*_
# @Time: 2021/12/09 16:05 
# @Author: yuyongsheng
# @Software: PyCharm
# @Description: 新华医院生脉注射液：计量预测建模40和60mg

# %%
# 导入程序包
import pymysql as MySQLDB
import pandas as pd
import numpy as np

import re
import sys
import os
project_path = os.getcwd()

# %%
# 字符串转换为时间格式
import datetime
def str_to_datetime(x):
    try:
        a = datetime.datetime.strptime(x, "%d/%m/%Y %H:%M:%S")
        return a
    except:
        return np.NaN

# %% [markdown]
# # 数据清洗

# %%
df_model=pd.read_excel(project_path+'/data/processed_data/df_1.10.6_人工删除不重要列.xlsx')
if 'Unnamed: 0' in df_model.columns:
    df_model = df_model.drop(['Unnamed: 0'], axis=1)

# %%
df_model['日剂量']=df_model['日剂量'].apply(lambda x: 1 if x==60 else 0)

# %%
df_model['日剂量'].value_counts()
# Out:
# 1    116
# 0     95
# Name: 日剂量, dtype: int64

# %%
print(df_model.shape)
# Out:
# (211, 51)

# %% [markdown]
# ## 删除无关特征

# %%
df_model.columns
# Out:
# Index(['受试者编号', '出院诊断', '主要疾病转归_描述', '用药开始时间', '用药结束时间', '用药天数', 'EXDSTXT',
#        '日剂量', '冠心病', '肺部感染', '心功能不全', '脑梗死', '房颤', '心肌梗塞', '呼吸系统疾病_label',
#        '神经系统疾病_label', '泌尿系统疾病_label', '内分泌和代谢疾病_label', '住院日期', '完成日期',
#        '住院时长', '年龄', '性别', '基础疾病', '降脂药', '降血小板药', '红细胞_入院', '血红蛋白_入院',
#        '白细胞_入院', '中性粒细胞计数_入院', '血小板_入院', '红细胞压积_入院', 'ALT_入院', 'AST_入院',
#        'GGT_入院', '低密度脂蛋白（LDL）_入院', '前白蛋白_入院', '尿素氮（BUN）_入院', '总胆红素（TBil）_入院',
#        '甘油三酯_入院', '白蛋白_入院', '直接胆红素（DBil）_入院', '肌酐（Cr）_入院', '胆固醇_入院', '血氯_入院',
#        '血钠_入院', '血钾_入院', '高密度脂蛋白胆固醇（HDLC）_入院', 'PT_入院', 'INR_入院', 'APTT_入院'],
#       dtype='object')

# %%
df_model=df_model.drop(['受试者编号', '出院诊断','主要疾病转归_描述', '用药开始时间', '用药结束时间','用药天数', 'EXDSTXT',
                        '冠心病','心肌梗塞', '呼吸系统疾病_label','神经系统疾病_label', '泌尿系统疾病_label', '内分泌和代谢疾病_label',
                        '住院日期', '完成日期', '住院时长', '血钠_入院','血钾_入院','血氯_入院'],axis=1)

# %%
df_model
# Out:
#      日剂量  肺部感染  心功能不全  脑梗死  房颤  年龄  性别  基础疾病  降脂药  降血小板药  ...  总胆红素（TBil）_入院  \
# 0      1     0      0    0   0  64   1     1    1      1  ...            NaN
# 1      1     0      0    0   0  61   0     1    0      1  ...            NaN
# 2      1     0      0    0   0  60   1     1    0      1  ...            NaN
# 3      1     0      0    0   0  71   1     0    0      1  ...            NaN
# 4      1     0      0    0   0  48   1     1    1      0  ...            NaN
# ..   ...   ...    ...  ...  ..  ..  ..   ...  ...    ...  ...            ...
# 206    0     0      1    0   0  83   1     1    0      0  ...           22.0
# 207    0     0      0    0   0  73   0     1    0      0  ...           16.8
# 208    1     1      1    0   0  81   0     0    0      0  ...            NaN
# 209    0     0      1    0   0  89   0     1    0      0  ...           12.3
# 210    0     0      0    0   0  59   1     0    1      0  ...           25.9
#
#      甘油三酯_入院  白蛋白_入院  直接胆红素（DBil）_入院  肌酐（Cr）_入院  胆固醇_入院  高密度脂蛋白胆固醇（HDLC）_入院  \
# 0       0.25    38.1             NaN       80.0    4.65                1.55
# 1       1.03    38.6             NaN       37.0     NaN                1.04
# 2       0.40    45.2             NaN       60.0    4.12                1.11
# 3       1.17    35.2             NaN       70.0    3.80                1.03
# 4       1.43    42.2             NaN       58.0    5.34                1.63
# ..       ...     ...             ...        ...     ...                 ...
# 206      NaN    41.7             0.0       99.5     NaN                 NaN
# 207     1.70    37.5             5.5       72.0    3.78                1.07
# 208      NaN     NaN             NaN        NaN     NaN                 NaN
# 209     0.49    35.5             3.6      124.0    4.93                1.64
# 210     1.77    36.6             8.7       78.0    3.70                1.02
#
#      PT_入院  INR_入院  APTT_入院
# 0     14.9    1.09     29.9
# 1     15.7    1.23     38.8
# 2     15.0    1.11     37.9
# 3     13.5    1.12     39.2
# 4     11.6    1.25     50.9
# ..     ...     ...      ...
# 206   15.2    1.37     31.7
# 207   11.3    1.05     27.7
# 208   15.4    1.17     29.6
# 209   11.2    1.02     30.6
# 210   11.7    1.06     36.0
#
# [211 rows x 32 columns]

# %%
df_model.shape
# Out:
# (211, 32)

# %%
df_model.columns
# Out:
# Index(['日剂量', '肺部感染', '心功能不全', '脑梗死', '房颤', '年龄', '性别', '基础疾病', '降脂药', '降血小板药',
#        '红细胞_入院', '血红蛋白_入院', '白细胞_入院', '中性粒细胞计数_入院', '血小板_入院', '红细胞压积_入院',
#        'ALT_入院', 'AST_入院', 'GGT_入院', '低密度脂蛋白（LDL）_入院', '前白蛋白_入院',
#        '尿素氮（BUN）_入院', '总胆红素（TBil）_入院', '甘油三酯_入院', '白蛋白_入院', '直接胆红素（DBil）_入院',
#        '肌酐（Cr）_入院', '胆固醇_入院', '高密度脂蛋白胆固醇（HDLC）_入院', 'PT_入院', 'INR_入院',
#        'APTT_入院'],
#       dtype='object')

# %%
corr_result=df_model[['日剂量', '肺部感染', '心功能不全', '脑梗死', '房颤', '年龄', '性别', '基础疾病', '降脂药', '降血小板药',
       '红细胞_入院', '血红蛋白_入院', '白细胞_入院', '中性粒细胞计数_入院', '血小板_入院', '红细胞压积_入院',
       'ALT_入院', 'AST_入院', 'GGT_入院', '低密度脂蛋白（LDL）_入院', '前白蛋白_入院',
       '尿素氮（BUN）_入院', '总胆红素（TBil）_入院', '甘油三酯_入院', '白蛋白_入院', '直接胆红素（DBil）_入院',
       '肌酐（Cr）_入院', '胆固醇_入院', '高密度脂蛋白胆固醇（HDLC）_入院', 'PT_入院', 'INR_入院',
       'APTT_入院']].corr()

# %%
corr_result[corr_result>0.5].to_excel(project_path+'/data/result/feature_engineering/corr.xlsx')

# %% [markdown]
# ## 删除缺失超过50%的特征

# %% [markdown]
# ### 删除列缺失超过50%的列

# %%
for i in df_model.columns:
    if df_model[i].isnull().sum()/df_model.shape[0] >= 0.5:
        print(i)
        del df_model[i]

# %%
print(df_model.shape)  # (106,101)
# Out:
# (211, 32)

# %% [markdown]
# ### 删除行缺失超过50%的行

# %%
df_model=df_model.reset_index(drop=True)
for i in range(df_model.shape[0]):
    if df_model.loc[i].isnull().sum()/df_model.loc[i].shape[0] >= 0.5:
        print(i)
        df_model.drop([i],axis=0,inplace=True)
# Out:
# 58
# 136

# %%
print(df_model.shape)
# Out:
# (209, 32)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/result/feature_engineering/df_1.3_删除缺失超过50%.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# ## 删除分类极不平衡的特征

# %%
# 保护目标变量、tdm数据
protect_col=['']
for i in [i for i in df_model.columns if i not in protect_col]:
    if df_model[i].nunique() < 2:
        del df_model[i]
        continue
    if df_model[i].nunique() == 2:
        # 如果分类变量中某一变量的占比超过90%，则删除该指标
        num_1 = df_model[i].value_counts()  # df一列中不同变量的数目
        num_2 = num_1.div(df_model.shape[0])  # div除法，所有元素都除以相同数值
        num_3 = num_2.max()  # 取出最大值
        if num_3 >= 0.9:
            print(i)
            del df_model[i]

# %%
df_model.shape
# Out:
# (209, 32)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/result/feature_engineering/df_1.4_删除分类极不平衡.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# ## 过滤异常值

# %%
# 过滤异常值，大于正常值超过100倍！
for i in df_model.columns[2:]:
    # 测试特征是否存在异常值
    median_value= max(df_model[i].median(),1)
    max_value = df_model[i].max()
    if max_value >= 100 * median_value:
        print(i)
    df_model[i]=df_model[i].apply(lambda x: np.nan if x<0 or x!=x else np.nan if float(x) >= 100*median_value else x)
# Out:
# 低密度脂蛋白（LDL）_入院

# %%
df_model.shape
# Out:
# (209, 32)

# %%
# 保存特征清洗
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_1_特征清洗.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# # 显著性分析

# %%
df_model.columns
# Out:
# Index(['日剂量', '肺部感染', '心功能不全', '脑梗死', '房颤', '年龄', '性别', '基础疾病', '降脂药', '降血小板药',
#        '红细胞_入院', '血红蛋白_入院', '白细胞_入院', '中性粒细胞计数_入院', '血小板_入院', '红细胞压积_入院',
#        'ALT_入院', 'AST_入院', 'GGT_入院', '低密度脂蛋白（LDL）_入院', '前白蛋白_入院',
#        '尿素氮（BUN）_入院', '总胆红素（TBil）_入院', '甘油三酯_入院', '白蛋白_入院', '直接胆红素（DBil）_入院',
#        '肌酐（Cr）_入院', '胆固醇_入院', '高密度脂蛋白胆固醇（HDLC）_入院', 'PT_入院', 'INR_入院',
#        'APTT_入院'],
#       dtype='object')

# %%
discrete_col=['肺部感染', '心功能不全', '脑梗死', '房颤','性别', '基础疾病', '降脂药', '降血小板药']
continuous_col=[x for x in df_model.columns if x not in discrete_col]
continuous_col.remove('日剂量')

# %% [markdown]
# ## 分类变量显著性分析

# %%
# 二分类卡方检验
from scipy.stats import chi2_contingency
feature_list=[]
y_list=[]
t_list=[]
p_list=[]
sig_list=[]
for i in discrete_col:
    print(i)
    result = chi2_contingency(pd.crosstab(df_model['日剂量'],df_model[i]))
    t,p=result[0:2]
    t=round(t,2)
    p=round(p,3)
    feature_list.append(i)
    y_list.append('卡方检验')
    t_list.append(t)
    p_list.append(p)
    if p <=0.05:
        sig='显著'
    else:
        sig='不显著'
    sig_list.append(sig)
# Out:
# 冠心病
# 肺部感染
# 心功能不全
# 脑梗死
# 房颤
# 心肌梗塞
# 呼吸系统疾病_label
# 神经系统疾病_label
# 泌尿系统疾病_label
# 内分泌和代谢疾病_label
# 性别
# 基础疾病
# 降脂药
# 降血小板药

# %%
df_discrete_sig=pd.DataFrame({'feature':feature_list,
                        '检验指标':y_list,
                        't值':t_list,
                        'p值':p_list,
                        'result':sig_list})

# %%
# 分类变量显著性检验
df_discrete_sig.to_excel(project_path+'/data/result/feature_engineering/df_2.1_分类变量显著性检验.xlsx')

# %%
df_discrete_sig
# Out:
#            feature  检验指标     t值     p值 result
# 0              冠心病  卡方检验   2.00  0.158    不显著
# 1             肺部感染  卡方检验  13.47  0.000     显著
# 2            心功能不全  卡方检验  18.46  0.000     显著
# 3              脑梗死  卡方检验   5.78  0.016     显著
# 4               房颤  卡方检验  20.37  0.000     显著
# 5             心肌梗塞  卡方检验  79.79  0.000     显著
# 6     呼吸系统疾病_label  卡方检验  14.74  0.000     显著
# 7     神经系统疾病_label  卡方检验  13.13  0.000     显著
# 8     泌尿系统疾病_label  卡方检验  11.95  0.001     显著
# 9   内分泌和代谢疾病_label  卡方检验   0.25  0.620    不显著
# 10              性别  卡方检验   7.09  0.008     显著
# 11            基础疾病  卡方检验   1.76  0.185    不显著
# 12             降脂药  卡方检验   7.60  0.006     显著
# 13           降血小板药  卡方检验   6.90  0.009     显著

# %%
discrete_relate=list(df_discrete_sig[df_discrete_sig.result=='显著']['feature'])

# %%
discrete_relate
# Out:
# ['肺部感染',
#  '心功能不全',
#  '脑梗死',
#  '房颤',
#  '心肌梗塞',
#  '呼吸系统疾病_label',
#  '神经系统疾病_label',
#  '泌尿系统疾病_label',
#  '性别',
#  '降脂药',
#  '降血小板药']

# %%
list(df_discrete_sig[df_discrete_sig.result=='不显著']['feature'])
# Out:
# ['冠心病', '内分泌和代谢疾病_label', '基础疾病']

# %%
# 保留业务需要的不显著变量
discrete_relate.extend(['冠心病', '基础疾病'])

# %% [markdown]
# ## 连续变量显著性分析

# %%
from scipy.stats import kstest,shapiro
##检验是否正态
def norm_test(data):
    if len(data) > 30:
        norm, p = kstest(data, 'norm')
    else:
        norm, p = shapiro(data)
    #print(t,p)
    if p>=0.05:
        return True
    else:
        return False

# %%
import scipy.stats as st
# 连续变量的显著性检验
def test2(data_b, data_p):
    if norm_test(data_b) and norm_test(data_p):
        x = 1
        y = '独立样本T检验'
        t, p = st.ttest_ind(list(data_b),list(data_p), nan_policy='omit')
    else:
        x = 0
        y = 'Mann-Whitney U检验'
        t,p = st.mannwhitneyu(list(data_b),list(data_p))
    return x,y,t,p

# %%
def sig_test(df_high,df_low,list1):

    feature_list=[]  # 特征列表
    y_list=[]  # 显著性检验方法
    t_list=[]  # 统计量
    p_list=[]  # p值
    result_list=[]  # 是否显著
    high_mean_list=[]
    low_mean_list=[]

    for i in list1:
        print(i)
        # 高剂量组统计
        df_high_nt=df_high[df_high[i].notnull()]
        data_high=df_high_nt[i]
        high_mean=round(data_high.mean(),2)
        
        df_low_nt=df_low[df_low[i].notnull()]
        data_low=df_low_nt[i]
        low_mean=round(data_low.mean(),2)

        # 计算高低剂量组显著性差异
        if data_high.shape[0] >= 10 and data_low.shape[0]>=10:
            # 连续变量检验
            x,y,t,p = test2(data_high, data_low)
            t=round(t,2)
            p=round(p,3)
            if p <=0.05:
                sig='显著'
            else:
                sig='不显著'
            # 显著性 
            feature_list.append(i)
            y_list.append(y)
            t_list.append(t)
            p_list.append(p)
            result_list.append(sig)
            high_mean_list.append(high_mean)
            low_mean_list.append(low_mean)

    df_result=pd.DataFrame({'特征':feature_list,
                            '高剂量均值':high_mean_list,
                            '低剂量均值':low_mean_list,
                            '检验指标':y_list,
                            't值':t_list,
                            'p值':p_list,
                            '显著性结果':result_list})
    return df_result

# %%
# 提取甲氨蝶呤不同标签
df_MTX_high = df_model[df_model['日剂量']==1]
df_MTX_low = df_model[df_model['日剂量']==0]

# %%
# 甲氨蝶呤高低剂量组PSM控制变量统计和显著性检验
df_MTX_PSM_sig = sig_test(df_MTX_high,df_MTX_low,continuous_col)
df_MTX_PSM_sig = df_MTX_PSM_sig.reset_index(drop=True)
# Out:
# 年龄
# 红细胞_入院
# 血红蛋白_入院
# 白细胞_入院
# 中性粒细胞计数_入院
# 血小板_入院
# 红细胞压积_入院
# ALT_入院
# AST_入院
# GGT_入院
# 低密度脂蛋白（LDL）_入院
# 前白蛋白_入院
# 尿素氮（BUN）_入院
# 总胆红素（TBil）_入院
# 甘油三酯_入院
# 白蛋白_入院
# 直接胆红素（DBil）_入院
# 肌酐（Cr）_入院
# 胆固醇_入院
# 高密度脂蛋白胆固醇（HDLC）_入院
# PT_入院
# INR_入院
# APTT_入院

# %%
# 保存高低剂量组PSM控制变量统计和显著性检验
writer=pd.ExcelWriter(project_path+r'/data/result/feature_engineering/df_2.2_连续变量相关性分析.xlsx')
df_MTX_PSM_sig.to_excel(writer)
writer.save()

# %%
df_MTX_PSM_sig
# Out:
#                     特征   高剂量均值   低剂量均值              检验指标      t值     p值 显著性结果
# 0                   年龄   66.75   76.26  Mann-Whitney U检验  3072.5  0.000    显著
# 1               红细胞_入院    4.40    4.19  Mann-Whitney U检验  2639.5  0.000    显著
# 2              血红蛋白_入院  131.96  117.61  Mann-Whitney U检验  3147.5  0.000    显著
# 3               白细胞_入院    9.24    7.74  Mann-Whitney U检验  3390.0  0.000    显著
# 4           中性粒细胞计数_入院   73.69   66.58  Mann-Whitney U检验  3573.5  0.000    显著
# 5               血小板_入院  200.79  186.42  Mann-Whitney U检验  4280.5  0.011    显著
# 6             红细胞压积_入院   39.70   34.48  Mann-Whitney U检验  2747.0  0.000    显著
# 7               ALT_入院   39.84   37.51  Mann-Whitney U检验  2700.5  0.000    显著
# 8               AST_入院  105.95   47.69  Mann-Whitney U检验  2035.0  0.000    显著
# 9               GGT_入院   54.69   39.03  Mann-Whitney U检验  1567.0  0.027    显著
# 10      低密度脂蛋白（LDL）_入院    2.70    2.00  Mann-Whitney U检验  1563.5  0.000    显著
# 11             前白蛋白_入院  216.45  172.33  Mann-Whitney U检验  1072.5  0.000    显著
# 12         尿素氮（BUN）_入院    6.65    8.80  Mann-Whitney U检验  3235.5  0.005    显著
# 13       总胆红素（TBil）_入院   14.53   14.14  Mann-Whitney U检验  2264.0  0.448   不显著
# 14             甘油三酯_入院    1.51    1.36  Mann-Whitney U检验  2836.0  0.100   不显著
# 15              白蛋白_入院   39.58   35.26  Mann-Whitney U检验  2256.5  0.000    显著
# 16      直接胆红素（DBil）_入院    4.48    3.76  Mann-Whitney U检验  1925.5  0.124   不显著
# 17           肌酐（Cr）_入院   92.05  124.20  Mann-Whitney U检验  3355.5  0.007    显著
# 18              胆固醇_入院    4.41    3.78  Mann-Whitney U检验  1946.0  0.000    显著
# 19  高密度脂蛋白胆固醇（HDLC）_入院    1.24    1.23  Mann-Whitney U检验  2731.5  0.177   不显著
# 20               PT_入院   14.06   13.45  Mann-Whitney U检验  3738.5  0.004    显著
# 21              INR_入院    1.12    1.31  Mann-Whitney U检验  4097.0  0.043    显著
# 22             APTT_入院   35.06   31.78  Mann-Whitney U检验  3637.5  0.002    显著

# %%
continuous_relate = list(df_MTX_PSM_sig[df_MTX_PSM_sig['显著性结果']=='显著']['特征'])

# %%
continuous_relate
# Out:
# ['年龄',
#  '红细胞_入院',
#  '血红蛋白_入院',
#  '白细胞_入院',
#  '中性粒细胞计数_入院',
#  '血小板_入院',
#  '红细胞压积_入院',
#  'ALT_入院',
#  'AST_入院',
#  'GGT_入院',
#  '低密度脂蛋白（LDL）_入院',
#  '前白蛋白_入院',
#  '尿素氮（BUN）_入院',
#  '白蛋白_入院',
#  '肌酐（Cr）_入院',
#  '胆固醇_入院',
#  'PT_入院',
#  'INR_入院',
#  'APTT_入院']

# %%
list(df_MTX_PSM_sig[df_MTX_PSM_sig['显著性结果']=='不显著']['特征'])
# Out:
# ['总胆红素（TBil）_入院', '甘油三酯_入院', '直接胆红素（DBil）_入院', '高密度脂蛋白胆固醇（HDLC）_入院']

# %%
# 业务角度需要保留：日剂量、age、MTX_tdm_24h、MTX_tdm_48h、MTX_tdm_72h
continuous_relate.extend(['甘油三酯_入院', '高密度脂蛋白胆固醇（HDLC）_入院'])

# %%
len(continuous_relate)
# Out:
# 21

# %%
# 提取相关性特征
feature_relate=discrete_col + continuous_relate
# 加入目标变量
feature_relate.insert(0,'日剂量')
df_model_relate=df_model[feature_relate]

# %%
df_model_relate.shape
# Out:
# (211, 36)

# %%
# 保存显著性分析结果
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_2_显著性清洗.xlsx')
df_model_relate.to_excel(writer)
writer.save()

# %% [markdown]
# # 重要性评分

# %%
df_model_relate.shape
# Out:
# (211, 36)

# %%
from sklearn.model_selection import train_test_split

# 划分训练集和测试集，比例为8:2
x = df_model_relate.drop(['日剂量'],axis=1)
y = df_model_relate['日剂量']
tran_x, test_x, tran_y, test_y = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
# 重要性
import catboost,xgboost
model_boost=xgboost.XGBClassifier(max_depth=5,
                                learning_rate=0.01,
                                n_estimators=500,
                                min_child_weight=0.5,
                                eta=0.1,
                                gamma=0.5,
                                reg_lambda=10,
                                subsample=0.5,
                                colsample_bytree=0.8,
                                nthread=4,
                                scale_pos_weight=1)
model_boost.fit(tran_x,tran_y)
importance = model_boost.feature_importances_
print(tran_x.columns)
print(importance)
# Out:
# Index(['冠心病', '肺部感染', '心功能不全', '脑梗死', '房颤', '心肌梗塞', '呼吸系统疾病_label',
#        '神经系统疾病_label', '泌尿系统疾病_label', '内分泌和代谢疾病_label', '性别', '基础疾病', '降脂药',
#        '降血小板药', '年龄', '红细胞_入院', '血红蛋白_入院', '白细胞_入院', '中性粒细胞计数_入院', '血小板_入院',
#        '红细胞压积_入院', 'ALT_入院', 'AST_入院', 'GGT_入院', '低密度脂蛋白（LDL）_入院', '前白蛋白_入院',
#        '尿素氮（BUN）_入院', '白蛋白_入院', '肌酐（Cr）_入院', '胆固醇_入院', 'PT_入院', 'INR_入院',
#        'APTT_入院', '甘油三酯_入院', '高密度脂蛋白胆固醇（HDLC）_入院'],
#       dtype='object')
# [0.01740049 0.02351424 0.03272203 0.01784054 0.02222119 0.11695194
#  0.03101369 0.02553946 0.01518009 0.02083292 0.01068432 0.02219264
#  0.02532904 0.0159172  0.02715487 0.04119671 0.02799737 0.02299884
#  0.02756116 0.0230635  0.04279627 0.01748092 0.02789039 0.04505711
#  0.04214743 0.03759498 0.02141228 0.04427367 0.02443977 0.02344657
#  0.02196564 0.02008634 0.02459048 0.0177881  0.02171778]

# %%
df_importance= pd.DataFrame(data={'特征':tran_x.columns,'重要性评分':importance})
df_importance['重要性评分']=df_importance['重要性评分'].apply(lambda x: round(x,3))
df_importance=df_importance.sort_values(['重要性评分'],ascending=False)
df_importance=df_importance.reset_index(drop=True)

# %%
df_importance.to_excel(project_path + '/data/result/feature_engineering/df_3_模型重要性评分.xlsx')

# %%
# 筛选重要特征组建建模数据
df_importance_select=df_importance[df_importance['重要性评分']>0]
select_list = list(df_importance_select['特征'])
select_list.insert(0,'日剂量')

# %%
df_model_importance = df_model_relate[select_list]

# %%
df_model_importance.shape
# Out:
# (211, 36)

# %%
# 保存重要性评分筛选后的建模数据
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_3_model_data_importance.xlsx')
df_model_importance.to_excel(writer)
writer.save()

# %% [markdown]
# # 逐步向前

# %% [markdown]
# ## 插补数据

# %%
# 使用随机森林对缺失值进行插补
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
def missing_value_interpolation(df):
    df = df.reset_index(drop=True)
    # 提取存在缺失值的列名
    missing_list = []
    for i in df.columns:
        if df[i].isnull().sum() > 0:
            missing_list.append(i)
    missing_list_copy = missing_list.copy()
    # 用该列未缺失的值训练随机森林，然后用训练好的rf预测缺失值
    for i in range(len(missing_list)):
        name=missing_list[0]
        df_missing = df[missing_list_copy]
        # 将其他列的缺失值用0表示。
        missing_list.remove(name)
        for j in missing_list:
            df_missing[j]=df_missing[j].astype('str').apply(lambda x: 0 if x=='nan' else x)
        df_missing_is = df_missing[df_missing[name].isnull()]
        df_missing_not = df_missing[df_missing[name].notnull()]
        y = df_missing_not[name]
        x = df_missing_not.drop([name],axis=1)
        # 列出参数列表
        tree_grid_parameter = {'n_estimators': list((10, 50, 100, 150, 200))}
        # 进行参数的搜索组合
        grid = GridSearchCV(RandomForestRegressor(),param_grid=tree_grid_parameter,cv=3)
        #rfr=RandomForestRegressor(random_state=0,n_estimators=100,n_jobs=-1)
        #根据已有数据去拟合随机森林模型
        grid.fit(x, y)
        rfr = RandomForestRegressor(n_estimators=grid.best_params_['n_estimators'])
        rfr.fit(x, y)
        #预测缺失值
        predict = rfr.predict(df_missing_is.drop([name],axis=1))
        #填补缺失值
        df.loc[df[name].isnull(),name] = predict
    return df

# %%
df_model_relate.shape
# Out:
# (211, 36)

# %%
df_model_cb=missing_value_interpolation(df_model_importance)
# df_model_cb=df_model_importance

# %% [markdown]
# ## 划分数据集和过采样

# %%
from sklearn.model_selection import train_test_split
# 划分训练集和测试集，比例为8:2
x = df_model_cb.drop(['日剂量'],axis=1)
y = df_model_cb['日剂量']

tran_x, test_x, tran_y, test_y = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
tran_x.shape
# Out:
# (168, 35)

# %%
tran_y
# Out:
# 55     0
# 40     1
# 54     1
# 48     1
# 56     1
#       ..
# 144    1
# 118    1
# 189    1
# 206    0
# 99     0
# Name: 日剂量, Length: 168, dtype: int64

# %%
# 进行过采样
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=0)

tran_x_sm,tran_y_sm = sm.fit_resample(tran_x,tran_y)

# %%
tran_x_sm.shape
# Out:
# (186, 35)

# %% [markdown]
# ## stepwise forward

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.ensemble import RandomForestClassifier

r2_max_list=[]
feature_max_list=[]
for i in range(1,tran_x_sm.shape[1]+1):
    # 津源xgboost模型
    sfs = SFS(xgboost.XGBClassifier(max_depth=5,
                        learning_rate=0.01,
                        n_estimators=300,
                        min_child_weight=0.5,
                        eta=0.1,
                        gamma=0.5,
                        reg_lambda=10,
                        subsample=0.5,
                        colsample_bytree=0.8,
                        nthread=4,
                        scale_pos_weight=1,
                        random_state=3),
              n_jobs=-1, # 并行使用的进程数，默认1个，如果设置为-1，该值为总的核数
              k_features=i,
             forward=True,
             floating=False,  
             verbose=2,  # 显示输出的一些参数，默认为0不输出
             scoring='accuracy', # for binary targets
             cv=3)  # cv交叉验证

    sfs = sfs.fit(tran_x_sm, tran_y_sm)
    # 逐步向前筛选结果，包括特征个数，最优特征组合及其r2
    sfs_result = sfs.subsets_
    df_sfs = pd.DataFrame(sfs_result)
    # 逐步向前结果
    r2_list=list(df_sfs.loc['avg_score'])
    feature_list=list(df_sfs.loc['feature_names'])
    # 保存特征组合
    r2_max_list.append(r2_list[-1])
    feature_max_list.append(feature_list[-1])
#     if i==4:
#         break
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    9.1s finished
#
# [2022-05-05 15:13:54] Features: 1/1 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.5s finished
#
# [2022-05-05 15:14:01] Features: 1/2 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    6.2s finished
#
# [2022-05-05 15:14:07] Features: 2/2 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.0s finished
#
# [2022-05-05 15:14:13] Features: 1/3 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.6s finished
#
# [2022-05-05 15:14:19] Features: 2/3 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.0s finished
#
# [2022-05-05 15:14:25] Features: 3/3 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.7s finished
#
# [2022-05-05 15:14:32] Features: 1/4 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.9s finished
#
# [2022-05-05 15:14:38] Features: 2/4 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.2s finished
#
# [2022-05-05 15:14:44] Features: 3/4 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.1s finished
#
# [2022-05-05 15:14:50] Features: 4/4 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.1s finished
#
# [2022-05-05 15:14:56] Features: 1/5 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.9s finished
#
# [2022-05-05 15:15:02] Features: 2/5 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.1s finished
#
# [2022-05-05 15:15:08] Features: 3/5 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.0s finished
#
# [2022-05-05 15:15:15] Features: 4/5 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.8s finished
#
# [2022-05-05 15:15:20] Features: 5/5 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.1s finished
#
# [2022-05-05 15:15:27] Features: 1/6 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.8s finished
#
# [2022-05-05 15:15:33] Features: 2/6 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.1s finished
#
# [2022-05-05 15:15:39] Features: 3/6 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    5.6s finished
#
# [2022-05-05 15:15:44] Features: 4/6 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.6s finished
#
# [2022-05-05 15:15:50] Features: 5/6 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.5s finished
#
# [2022-05-05 15:15:56] Features: 6/6 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    5.9s finished
#
# [2022-05-05 15:16:02] Features: 1/7 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.6s finished
#
# [2022-05-05 15:16:07] Features: 2/7 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    5.8s finished
#
# [2022-05-05 15:16:13] Features: 3/7 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    5.6s finished
#
# [2022-05-05 15:16:19] Features: 4/7 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.6s finished
#
# [2022-05-05 15:16:25] Features: 5/7 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.5s finished
#
# [2022-05-05 15:16:30] Features: 6/7 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.3s finished
#
# [2022-05-05 15:16:36] Features: 7/7 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    5.8s finished
#
# [2022-05-05 15:16:42] Features: 1/8 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.8s finished
#
# [2022-05-05 15:16:48] Features: 2/8 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.3s finished
#
# [2022-05-05 15:16:54] Features: 3/8 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.4s finished
#
# [2022-05-05 15:17:01] Features: 4/8 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.1s finished
#
# [2022-05-05 15:17:07] Features: 5/8 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.0s finished
#
# [2022-05-05 15:17:13] Features: 6/8 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s finished
#
# [2022-05-05 15:17:18] Features: 7/8 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s finished
#
# [2022-05-05 15:17:24] Features: 8/8 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    5.9s finished
#
# [2022-05-05 15:17:30] Features: 1/9 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.6s finished
#
# [2022-05-05 15:17:36] Features: 2/9 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    5.7s finished
#
# [2022-05-05 15:17:41] Features: 3/9 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    5.8s finished
#
# [2022-05-05 15:17:47] Features: 4/9 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.6s finished
#
# [2022-05-05 15:17:53] Features: 5/9 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.5s finished
#
# [2022-05-05 15:17:59] Features: 6/9 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.7s finished
#
# [2022-05-05 15:18:04] Features: 7/9 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.4s finished
#
# [2022-05-05 15:18:10] Features: 8/9 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.4s finished
#
# [2022-05-05 15:18:15] Features: 9/9 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.4s finished
#
# [2022-05-05 15:18:22] Features: 1/10 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    6.0s finished
#
# [2022-05-05 15:18:28] Features: 2/10 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.0s finished
#
# [2022-05-05 15:18:34] Features: 3/10 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.3s finished
#
# [2022-05-05 15:18:40] Features: 4/10 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.7s finished
#
# [2022-05-05 15:18:46] Features: 5/10 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.6s finished
#
# [2022-05-05 15:18:52] Features: 6/10 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.7s finished
#
# [2022-05-05 15:18:58] Features: 7/10 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 15:19:03] Features: 8/10 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-05-05 15:19:09] Features: 9/10 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.2s finished
#
# [2022-05-05 15:19:14] Features: 10/10 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    5.9s finished
#
# [2022-05-05 15:19:20] Features: 1/11 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.9s finished
#
# [2022-05-05 15:19:26] Features: 2/11 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.4s finished
#
# [2022-05-05 15:19:33] Features: 3/11 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.8s finished
#
# [2022-05-05 15:19:40] Features: 4/11 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.1s finished
#
# [2022-05-05 15:19:46] Features: 5/11 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.8s finished
#
# [2022-05-05 15:19:52] Features: 6/11 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.9s finished
#
# [2022-05-05 15:19:58] Features: 7/11 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 15:20:04] Features: 8/11 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-05-05 15:20:09] Features: 9/11 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.9s finished
#
# [2022-05-05 15:20:15] Features: 10/11 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.5s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.9s finished
#
# [2022-05-05 15:20:21] Features: 11/11 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.4s finished
#
# [2022-05-05 15:20:28] Features: 1/12 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.9s finished
#
# [2022-05-05 15:20:34] Features: 2/12 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.0s finished
#
# [2022-05-05 15:20:40] Features: 3/12 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.0s finished
#
# [2022-05-05 15:20:46] Features: 4/12 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.1s finished
#
# [2022-05-05 15:20:52] Features: 5/12 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.3s finished
#
# [2022-05-05 15:20:59] Features: 6/12 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    6.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    6.6s finished
#
# [2022-05-05 15:21:05] Features: 7/12 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 15:21:11] Features: 8/12 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.4s finished
#
# [2022-05-05 15:21:16] Features: 9/12 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.5s finished
#
# [2022-05-05 15:21:22] Features: 10/12 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.4s finished
#
# [2022-05-05 15:21:28] Features: 11/12 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.8s finished
#
# [2022-05-05 15:21:32] Features: 12/12 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.2s finished
#
# [2022-05-05 15:21:39] Features: 1/13 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    6.4s finished
#
# [2022-05-05 15:21:45] Features: 2/13 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.9s finished
#
# [2022-05-05 15:21:52] Features: 3/13 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.6s finished
#
# [2022-05-05 15:21:59] Features: 4/13 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.0s finished
#
# [2022-05-05 15:22:05] Features: 5/13 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.8s finished
#
# [2022-05-05 15:22:11] Features: 6/13 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s finished
#
# [2022-05-05 15:22:17] Features: 7/13 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 15:22:22] Features: 8/13 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-05-05 15:22:28] Features: 9/13 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.7s finished
#
# [2022-05-05 15:22:34] Features: 10/13 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.0s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.4s finished
#
# [2022-05-05 15:22:39] Features: 11/13 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    5.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    5.2s finished
#
# [2022-05-05 15:22:45] Features: 12/13 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.5s finished
#
# [2022-05-05 15:22:49] Features: 13/13 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.1s finished
#
# [2022-05-05 15:22:56] Features: 1/14 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.8s finished
#
# [2022-05-05 15:23:01] Features: 2/14 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.1s finished
#
# [2022-05-05 15:23:08] Features: 3/14 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.0s finished
#
# [2022-05-05 15:23:14] Features: 4/14 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.0s finished
#
# [2022-05-05 15:23:20] Features: 5/14 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.6s finished
#
# [2022-05-05 15:23:25] Features: 6/14 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s finished
#
# [2022-05-05 15:23:31] Features: 7/14 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 15:23:37] Features: 8/14 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-05-05 15:23:42] Features: 9/14 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.3s finished
#
# [2022-05-05 15:23:48] Features: 10/14 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    4.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.1s finished
#
# [2022-05-05 15:23:53] Features: 11/14 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.7s finished
#
# [2022-05-05 15:23:58] Features: 12/14 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.5s finished
#
# [2022-05-05 15:24:02] Features: 13/14 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.5s finished
#
# [2022-05-05 15:24:07] Features: 14/14 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    7.5s finished
#
# [2022-05-05 15:24:15] Features: 1/15 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    6.3s finished
#
# [2022-05-05 15:24:21] Features: 2/15 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.3s finished
#
# [2022-05-05 15:24:27] Features: 3/15 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    5.9s finished
#
# [2022-05-05 15:24:33] Features: 4/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.9s finished
#
# [2022-05-05 15:24:39] Features: 5/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.7s finished
#
# [2022-05-05 15:24:45] Features: 6/15 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s finished
#
# [2022-05-05 15:24:51] Features: 7/15 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 15:24:56] Features: 8/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.3s finished
#
# [2022-05-05 15:25:02] Features: 9/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.3s finished
#
# [2022-05-05 15:25:07] Features: 10/15 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    4.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.1s finished
#
# [2022-05-05 15:25:13] Features: 11/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.7s finished
#
# [2022-05-05 15:25:17] Features: 12/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.6s finished
#
# [2022-05-05 15:25:22] Features: 13/15 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.4s finished
#
# [2022-05-05 15:25:27] Features: 14/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    4.2s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    4.2s finished
#
# [2022-05-05 15:25:31] Features: 15/15 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.1s finished
#
# [2022-05-05 15:25:37] Features: 1/16 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.8s finished
#
# [2022-05-05 15:25:43] Features: 2/16 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.1s finished
#
# [2022-05-05 15:25:49] Features: 3/16 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    5.9s finished
#
# [2022-05-05 15:25:55] Features: 4/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.9s finished
#
# [2022-05-05 15:26:01] Features: 5/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.7s finished
#
# [2022-05-05 15:26:07] Features: 6/16 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.6s finished
#
# [2022-05-05 15:26:13] Features: 7/16 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 15:26:18] Features: 8/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    6.1s finished
#
# [2022-05-05 15:26:25] Features: 9/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.4s finished
#
# [2022-05-05 15:26:30] Features: 10/16 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    4.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.2s finished
#
# [2022-05-05 15:26:35] Features: 11/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.9s finished
#
# [2022-05-05 15:26:40] Features: 12/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.6s finished
#
# [2022-05-05 15:26:45] Features: 13/16 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.7s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.7s finished
#
# [2022-05-05 15:26:50] Features: 14/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    4.4s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    4.4s finished
#
# [2022-05-05 15:26:54] Features: 15/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    4.1s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    4.9s finished
#
# [2022-05-05 15:26:59] Features: 16/16 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.4s finished
#
# [2022-05-05 15:27:06] Features: 1/17 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.7s finished
#
# [2022-05-05 15:27:12] Features: 2/17 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    5.9s finished
#
# [2022-05-05 15:27:18] Features: 3/17 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.6s finished
#
# [2022-05-05 15:27:24] Features: 4/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.8s finished
#
# [2022-05-05 15:27:30] Features: 5/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.9s finished
#
# [2022-05-05 15:27:36] Features: 6/17 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    6.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    6.5s finished
#
# [2022-05-05 15:27:43] Features: 7/17 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.7s finished
#
# [2022-05-05 15:27:49] Features: 8/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.6s finished
#
# [2022-05-05 15:27:55] Features: 9/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    6.1s finished
#
# [2022-05-05 15:28:01] Features: 10/17 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    4.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.0s finished
#
# [2022-05-05 15:28:06] Features: 11/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.9s finished
#
# [2022-05-05 15:28:11] Features: 12/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.6s finished
#
# [2022-05-05 15:28:16] Features: 13/17 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.5s finished
#
# [2022-05-05 15:28:20] Features: 14/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    4.4s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    4.4s finished
#
# [2022-05-05 15:28:25] Features: 15/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    3.3s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    4.1s finished
#
# [2022-05-05 15:28:29] Features: 16/17 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    3.3s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    3.9s finished
#
# [2022-05-05 15:28:33] Features: 17/17 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.2s finished
#
# [2022-05-05 15:28:39] Features: 1/18 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.7s finished
#
# [2022-05-05 15:28:45] Features: 2/18 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.5s finished
#
# [2022-05-05 15:28:52] Features: 3/18 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.9s finished
#
# [2022-05-05 15:28:59] Features: 4/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    5.8s finished
#
# [2022-05-05 15:29:05] Features: 5/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.6s finished
#
# [2022-05-05 15:29:10] Features: 6/18 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s finished
#
# [2022-05-05 15:29:16] Features: 7/18 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.4s finished
#
# [2022-05-05 15:29:21] Features: 8/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.3s finished
#
# [2022-05-05 15:29:27] Features: 9/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.2s finished
#
# [2022-05-05 15:29:32] Features: 10/18 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    4.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.0s finished
#
# [2022-05-05 15:29:37] Features: 11/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.7s finished
#
# [2022-05-05 15:29:42] Features: 12/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.5s finished
#
# [2022-05-05 15:29:47] Features: 13/18 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.4s finished
#
# [2022-05-05 15:29:51] Features: 14/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    4.2s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    4.2s finished
#
# [2022-05-05 15:29:55] Features: 15/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    3.3s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    4.1s finished
#
# [2022-05-05 15:30:00] Features: 16/18 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    3.3s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    3.9s finished
#
# [2022-05-05 15:30:04] Features: 17/18 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:    3.3s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    3.9s finished
#
# [2022-05-05 15:30:08] Features: 18/18 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.0s finished
#
# [2022-05-05 15:30:14] Features: 1/19 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    5.8s finished
#
# [2022-05-05 15:30:20] Features: 2/19 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.0s finished
#
# [2022-05-05 15:30:26] Features: 3/19 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.5s finished
#
# [2022-05-05 15:30:32] Features: 4/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.6s finished
#
# [2022-05-05 15:30:39] Features: 5/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.9s finished
#
# [2022-05-05 15:30:45] Features: 6/19 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s finished
#
# [2022-05-05 15:30:51] Features: 7/19 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.9s finished
#
# [2022-05-05 15:30:57] Features: 8/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-05-05 15:31:03] Features: 9/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.4s finished
#
# [2022-05-05 15:31:08] Features: 10/19 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    4.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.2s finished
#
# [2022-05-05 15:31:13] Features: 11/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.8s finished
#
# [2022-05-05 15:31:18] Features: 12/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.9s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.9s finished
#
# [2022-05-05 15:31:23] Features: 13/19 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.8s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.9s finished
#
# [2022-05-05 15:31:28] Features: 14/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    5.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    5.1s finished
#
# [2022-05-05 15:31:33] Features: 15/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    3.4s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    4.3s finished
#
# [2022-05-05 15:31:38] Features: 16/19 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    3.5s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    4.2s finished
#
# [2022-05-05 15:31:42] Features: 17/19 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:    3.4s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    4.0s finished
#
# [2022-05-05 15:31:46] Features: 18/19 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    3.4s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    3.9s finished
#
# [2022-05-05 15:31:50] Features: 19/19 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.8s finished
#
# [2022-05-05 15:31:57] Features: 1/20 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    6.1s finished
#
# [2022-05-05 15:32:03] Features: 2/20 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.1s finished
#
# [2022-05-05 15:32:09] Features: 3/20 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.1s finished
#
# [2022-05-05 15:32:16] Features: 4/20 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.5s finished
#
# [2022-05-05 15:32:22] Features: 5/20 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    6.4s finished
#
# [2022-05-05 15:32:29] Features: 6/20 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s finished
#
# [2022-05-05 15:32:35] Features: 7/20 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.4s finished
#
# ...
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.5s finished
#
# [2022-05-05 16:01:02] Features: 14/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    4.4s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    4.4s finished
#
# [2022-05-05 16:01:07] Features: 15/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    3.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    4.0s finished
#
# [2022-05-05 16:01:11] Features: 16/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    3.3s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    3.9s finished
#
# [2022-05-05 16:01:15] Features: 17/34 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:    3.5s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    4.1s finished
#
# [2022-05-05 16:01:19] Features: 18/34 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    3.3s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    3.7s finished
#
# [2022-05-05 16:01:23] Features: 19/34 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    3.6s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    3.6s finished
#
# [2022-05-05 16:01:27] Features: 20/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    1.9s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    3.3s finished
#
# [2022-05-05 16:01:30] Features: 21/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    1.6s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    2.8s finished
#
# [2022-05-05 16:01:33] Features: 22/34 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    1.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    2.7s finished
#
# [2022-05-05 16:01:36] Features: 23/34 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    1.7s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    2.6s finished
#
# [2022-05-05 16:01:39] Features: 24/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    1.6s remaining:    7.6s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    1.7s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    2.3s finished
#
# [2022-05-05 16:01:41] Features: 25/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.2s finished
#
# [2022-05-05 16:01:43] Features: 26/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    1.6s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    2.1s finished
#
# [2022-05-05 16:01:45] Features: 27/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.7s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.7s finished
#
# [2022-05-05 16:01:47] Features: 28/34 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    1.4s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.5s finished
#
# [2022-05-05 16:01:49] Features: 29/34 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    1.4s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    1.4s finished
#
# [2022-05-05 16:01:50] Features: 30/34 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.1s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.1s finished
#
# [2022-05-05 16:01:52] Features: 31/34 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.9s finished
#
# [2022-05-05 16:01:53] Features: 32/34 -- score: 0.8064516129032259[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
#
# [2022-05-05 16:01:53] Features: 33/34 -- score: 0.8010752688172044[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.6s finished
#
# [2022-05-05 16:01:54] Features: 34/34 -- score: 0.7956989247311829[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    6.8s finished
#
# [2022-05-05 16:02:01] Features: 1/35 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    6.0s finished
#
# [2022-05-05 16:02:07] Features: 2/35 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    6.1s finished
#
# [2022-05-05 16:02:13] Features: 3/35 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    6.2s finished
#
# [2022-05-05 16:02:20] Features: 4/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    6.0s finished
#
# [2022-05-05 16:02:26] Features: 5/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    5.7s finished
#
# [2022-05-05 16:02:32] Features: 6/35 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s finished
#
# [2022-05-05 16:02:37] Features: 7/35 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.5s finished
#
# [2022-05-05 16:02:43] Features: 8/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.4s finished
#
# [2022-05-05 16:02:48] Features: 9/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.1s finished
#
# [2022-05-05 16:02:54] Features: 10/35 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    4.6s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    4.9s finished
#
# [2022-05-05 16:02:59] Features: 11/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    4.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    4.7s finished
#
# [2022-05-05 16:03:03] Features: 12/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    4.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    4.4s finished
#
# [2022-05-05 16:03:08] Features: 13/35 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.3s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.3s finished
#
# [2022-05-05 16:03:12] Features: 14/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    4.2s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    4.2s finished
#
# [2022-05-05 16:03:17] Features: 15/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    3.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    3.9s finished
#
# [2022-05-05 16:03:21] Features: 16/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    3.2s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    3.9s finished
#
# [2022-05-05 16:03:25] Features: 17/35 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:    3.5s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    4.2s finished
#
# [2022-05-05 16:03:29] Features: 18/35 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    3.6s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    4.0s finished
#
# [2022-05-05 16:03:33] Features: 19/35 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    3.5s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    3.6s finished
#
# [2022-05-05 16:03:37] Features: 20/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    1.6s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    3.0s finished
#
# [2022-05-05 16:03:40] Features: 21/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    1.6s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    2.8s finished
#
# [2022-05-05 16:03:43] Features: 22/35 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    1.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    2.6s finished
#
# [2022-05-05 16:03:46] Features: 23/35 -- score: 0.8279569892473119[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    1.6s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    2.5s finished
#
# [2022-05-05 16:03:48] Features: 24/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    1.6s remaining:    7.6s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    1.7s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    2.4s finished
#
# [2022-05-05 16:03:51] Features: 25/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    1.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.2s finished
#
# [2022-05-05 16:03:53] Features: 26/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    1.7s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    2.1s finished
#
# [2022-05-05 16:03:55] Features: 27/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.6s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.7s finished
#
# [2022-05-05 16:03:57] Features: 28/35 -- score: 0.8225806451612904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    1.5s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.5s finished
#
# [2022-05-05 16:03:58] Features: 29/35 -- score: 0.8172043010752689[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    1.2s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    1.3s finished
#
# [2022-05-05 16:04:00] Features: 30/35 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.0s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.0s finished
#
# [2022-05-05 16:04:01] Features: 31/35 -- score: 0.8118279569892474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.8s finished
#
# [2022-05-05 16:04:02] Features: 32/35 -- score: 0.8064516129032259[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.7s finished
#
# [2022-05-05 16:04:03] Features: 33/35 -- score: 0.8010752688172044[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.5s finished
#
# [2022-05-05 16:04:03] Features: 34/35 -- score: 0.7956989247311829[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.3s finished
#
# [2022-05-05 16:04:04] Features: 35/35 -- score: 0.7903225806451614

# %%
df_forward_result=pd.DataFrame(data={'auc':r2_max_list,
                                    'feature_names':feature_max_list})

# %%
df_forward_result.shape
# Out:
# (35, 2)

# %%
# 保存模型测试和测试结果到本地文件
df_forward_result.to_excel(project_path + '/data/result/feature_engineering/df_4.3_逐步向前特征测试结果.xlsx')

# %% [markdown]
# ## 逐步向前画图

# %%
df_forward_result =pd.read_excel(project_path +'/data/result/feature_engineering/df_4.3_逐步向前特征测试结果_RF.xlsx')
if 'Unnamed: 0' in df_forward_result.columns:
    df_forward_result = df_forward_result.drop(['Unnamed: 0'], axis=1)

# %%
df_forward_result.head()
# Out:
#         auc                                   feature_names
# 0  0.811828                                       ('心肌梗塞',)
# 1  0.811828                               ('心肌梗塞', '心功能不全')
# 2  0.822581                     ('心肌梗塞', '心功能不全', 'ALT_入院')
# 3  0.849462            ('心肌梗塞', '心功能不全', 'ALT_入院', '降血小板药')
# 4  0.844086  ('心肌梗塞', '心功能不全', '胆固醇_入院', 'ALT_入院', '降血小板药')

# %%
f1_max_list=list(df_forward_result['auc'])
feature_max_list=list(df_forward_result['feature_names'])

# %%
# 画图
# 如果模型画图不好，可以选择在excel中画图
import matplotlib.pyplot as plt
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['SimHei']  ##绘图显示中文
mpl.rcParams['axes.unicode_minus'] = False

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import rc
rc('mathtext', default='regular')


# r2折线图
# 分辨率参数-dpi，画布大小参数-figsize
plt.figure(figsize=(30,10))
plt.plot(list(range(1,len(f1_max_list)+1)),f1_max_list,
         color=(0.32941176470588235, 0.7294117647058823, 0.7490196078431373), label='AUC',linewidth=3) # 线粗细
# 设置坐标刻度值的大小
plt.tick_params(labelsize=23)

# 设置横纵坐标标题的名称以及对应字体格式
font_x = {'family': 'Times New Roman',
         'weight': 'normal',
         'size': 30,}
plt.xlabel('Number of Ranked features',font_x)
plt.ylabel('AUC',font_x)

# 设置横纵坐标刻度范围、间隔、名称
# x_list=list(df_feature['特征'])
plt.xticks(range(1,len(f1_max_list)+1,3))
# plt.yticks(list(range(len(f1_list))),f1_list,rotation=285)
# plt.legend(bbox_to_anchor=(1.1,1))  # 显示图例
# Out:
# ([<matplotlib.axis.XTick at 0x2147c6e3e10>,
#   <matplotlib.axis.XTick at 0x2147d9a9f98>,
#   <matplotlib.axis.XTick at 0x2147d9a9ac8>,
#   <matplotlib.axis.XTick at 0x2147d931b00>,
#   <matplotlib.axis.XTick at 0x2147d931da0>,
#   <matplotlib.axis.XTick at 0x2147d9a1c88>,
#   <matplotlib.axis.XTick at 0x2147d9a1ac8>,
#   <matplotlib.axis.XTick at 0x2147dab1240>,
#   <matplotlib.axis.XTick at 0x2147dab16d8>,
#   <matplotlib.axis.XTick at 0x2147dab1b70>,
#   <matplotlib.axis.XTick at 0x2147dab8048>,
#   <matplotlib.axis.XTick at 0x2147dab84e0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## 保存逐步向前筛选的建模数据

# %%
f1_max_index=f1_max_list.index(max(f1_max_list))
print(f1_max_index)
feature_com_best=df_forward_result.loc[f1_max_index,'feature_names']
print(feature_com_best)
# Out:
# 17
# ('心肌梗塞', 'GGT_入院', '前白蛋白_入院', '心功能不全', '中性粒细胞计数_入院', '年龄', '神经系统疾病_label', '降脂药', 'APTT_入院', '肺部感染', '胆固醇_入院', 'PT_入院', '高密度脂蛋白胆固醇（HDLC）_入院', '房颤', '尿素氮（BUN）_入院', '内分泌和代谢疾病_label', 'ALT_入院', '降血小板药')

# %%
feature_list=str(feature_com_best).split('\'')
feature_forward_select=feature_list[1:-1:2]
# 查找文献，判断变量是否与目标变量相关
feature_forward_select.remove('心肌梗塞')
feature_forward_select.insert(0,'日剂量')

# %%
len(feature_forward_select)
# Out:
# 18

# %%
feature_forward_select
# Out:
# ['日剂量',
#  'GGT_入院',
#  '前白蛋白_入院',
#  '心功能不全',
#  '中性粒细胞计数_入院',
#  '年龄',
#  '神经系统疾病_label',
#  '降脂药',
#  'APTT_入院',
#  '肺部感染',
#  '胆固醇_入院',
#  'PT_入院',
#  '高密度脂蛋白胆固醇（HDLC）_入院',
#  '房颤',
#  '尿素氮（BUN）_入院',
#  '内分泌和代谢疾病_label',
#  'ALT_入院',
#  '降血小板药']

# %%
df_model_forward=df_model[feature_forward_select]
df_model_forward.to_excel(project_path+'/data/result/feature_engineering/df_4.5_model_data_forward.xlsx')
