# %%
# _*_ coding: utf-8 _*_
# @Time: 2021/12/09 16:05 
# @Author: yuyongsheng
# @Software: PyCharm
# @Description: 新华医院生脉注射液：1. 逐步向前 2. 建模

# %%
# 导入程序包
import pymysql as MySQLDB
import pandas as pd
import numpy as np

import re
import sys
import os
project_path = os.getcwd()

# %%
# 字符串转换为时间格式
import datetime
def str_to_datetime(x):
    try:
        a = datetime.datetime.strptime(x, "%d/%m/%Y %H:%M:%S")
        return a
    except:
        return np.NaN

# %%
# 使用随机森林对缺失值进行插补
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
def missing_value_interpolation(df,missing_list=[]):
    df = df.reset_index(drop=True)
    # 提取存在缺失值的列名
    if not missing_list:
        for i in df.columns:
            if df[i].isnull().sum() > 0:
                missing_list.append(i)
    missing_list_copy = missing_list.copy()
    # 用该列未缺失的值训练随机森林，然后用训练好的rf预测缺失值
    for i in range(len(missing_list)):
        name=missing_list[0]
        df_missing = df[missing_list_copy]
        # 将其他列的缺失值用0表示。
        missing_list.remove(name)
        for j in missing_list:
            df_missing[j]=df_missing[j].astype('str').apply(lambda x: 0 if x=='nan' else x)
        df_missing_is = df_missing[df_missing[name].isnull()]
        df_missing_not = df_missing[df_missing[name].notnull()]
        y = df_missing_not[name]
        x = df_missing_not.drop([name],axis=1)
        # 列出参数列表
        tree_grid_parameter = {'n_estimators': list((10, 50, 100, 150, 200))}
        # 进行参数的搜索组合
        grid = GridSearchCV(RandomForestRegressor(),param_grid=tree_grid_parameter,cv=3)
        #rfr=RandomForestRegressor(random_state=0,n_estimators=100,n_jobs=-1)
        #根据已有数据去拟合随机森林模型
        grid.fit(x, y)
        rfr = RandomForestRegressor(n_estimators=grid.best_params_['n_estimators'])
        rfr.fit(x, y)
        #预测缺失值
        predict = rfr.predict(df_missing_is.drop([name],axis=1))
        #填补缺失值
        df.loc[df[name].isnull(),name] = predict
    return df

# %% [markdown]
# # 数据清洗

# %%
df_model=pd.read_excel(project_path+'/data/数据清洗结果.xlsx')
if 'Unnamed: 0' in df_model.columns:
    df_model = df_model.drop(['Unnamed: 0'], axis=1)

# %%
print(df_model.shape)
# Out:
# (737, 63)

# %% [markdown]
# ## 改名

# %%
df_model.rename(columns={'主要疾病转归_描述':'class'},inplace=True)

# %%
df_model
# Out:
#        受试者编号  class  年龄  性别  冠心病  肺部感染  糖尿病  高血压  心功能不全  脑梗死  ...  \
# 0    90001_a      0  61   1    0     0    0    1      0    1  ...
# 1    90003_a      1  53   0    0     0    0    1      0    0  ...
# 2    90004_a      0  70   0    0     0    0    1      1    0  ...
# 3    90005_a      0  70   0    0     0    0    1      0    0  ...
# 4    90006_a      0  79   1    0     0    0    1      0    1  ...
# ..       ...    ...  ..  ..  ...   ...  ...  ...    ...  ...  ...
# 732  90100_b      0  85   0    1     0    1    1      1    0  ...
# 733  90101_b      0  70   1    1     0    1    1      0    0  ...
# 734  90102_b      0  64   0    1     0    0    0      0    0  ...
# 735  90104_b      0  82   1    0     1    0    1      1    0  ...
# 736  90105_b      0  73   0    0     0    0    1      1    0  ...
#
#      总胆红素（TBil）变化率  直接胆红素（DBil）_入院  直接胆红素（DBil）_出院前  直接胆红素（DBil）变化率  \
# 0        -0.524194             0.0              2.3       229.00000
# 1              NaN             0.0              NaN             NaN
# 2              NaN             2.1              NaN             NaN
# 3        -0.653595             0.0              2.9       289.00000
# 4         0.246479             3.2              5.1         0.59375
# ..             ...             ...              ...             ...
# 732            NaN             NaN              NaN             NaN
# 733            NaN             NaN              NaN             NaN
# 734            NaN             NaN              NaN             NaN
# 735            NaN             NaN              NaN             NaN
# 736            NaN             NaN              NaN             NaN
#
#      尿素氮（BUN）_入院  尿素氮（BUN）_出院前  尿素氮（BUN）变化率  尿蛋白（PRO）_入院  尿蛋白（PRO）_出院前  \
# 0           9.60          4.03    -0.580208         25.0           NaN
# 1           6.00           NaN          NaN          NaN           NaN
# 2          14.00           NaN          NaN          NaN           NaN
# 3          21.40         20.84    -0.026168          NaN           NaN
# 4           4.41          5.71     0.294785          0.1           NaN
# ..           ...           ...          ...          ...           ...
# 732        21.84           NaN          NaN         75.0           NaN
# 733         9.00           NaN          NaN          NaN           NaN
# 734          NaN           NaN          NaN          0.1           NaN
# 735         6.64           NaN          NaN          NaN           NaN
# 736        21.97           NaN          NaN          NaN           NaN
#
#      尿蛋白（PRO）变化率
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 732          NaN
# 733          NaN
# 734          NaN
# 735          NaN
# 736          NaN
#
# [737 rows x 63 columns]

# %% [markdown]
# ## 删除无关特征

# %%
df_model=df_model.drop(['受试者编号'],axis=1)

# %%
df_model.shape
# Out:
# (737, 62)

# %% [markdown]
# ## 删除缺失超过50%的特征

# %% [markdown]
# ### 删除列缺失超过50%的列

# %%
for i in df_model.columns:
    if df_model[i].isnull().sum()/df_model.shape[0] >= 0.5:
        print(i)
        del df_model[i]
# Out:
# 血小板_出院前
# 血小板变化率
# INR_出院前
# INR变化率
# 总胆红素（TBil）_出院前
# 总胆红素（TBil）变化率
# 直接胆红素（DBil）_出院前
# 直接胆红素（DBil）变化率
# 尿素氮（BUN）_出院前
# 尿素氮（BUN）变化率
# 尿蛋白（PRO）_出院前
# 尿蛋白（PRO）变化率

# %%
print(df_model.shape)  # (106,101)
# Out:
# (737, 50)

# %% [markdown]
# ### 删除缺失超过50%的行

# %%
df_model=df_model.reset_index(drop=True)
for i in range(df_model.shape[0]):
    if df_model.loc[i].isnull().sum()/df_model.loc[i].shape[0] >= 0.5:
        print(i)
        df_model.drop([i],axis=0,inplace=True)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/feature_engineering/df_1.3_删除缺失超过50%.xlsx')
df_model.to_excel(writer)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-115-e38b40b5adb9> in <module>
#       2 writer=pd.ExcelWriter(project_path+'/data/feature_engineering/df_1.3_删除缺失超过50%.xlsx')
#       3 df_model.to_excel(writer)
# ----> 4 writer.save()
#
# D:\Anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     191         Save workbook to disk.
#     192         """
# --> 193         return self.book.close()
#     194
#     195     def write_cells(
#
# D:\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     304         if not self.fileclosed:
#     305             self.fileclosed = 1
# --> 306             self._store_workbook()
#     307
#     308     def set_size(self, width, height):
#
# D:\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     653
#     654         xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 655                             allowZip64=self.allow_zip64)
#     656
#     657         # Add XML sub-files to the Zip file with their Excel filename.
#
# D:\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1111             while True:
#    1112                 try:
# -> 1113                     self.fp = io.open(file, filemode)
#    1114                 except OSError:
#    1115                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'D:\\PycharmProjects\\SUP_xinhua_hospital/data/feature_engineering/df_1.3_删除缺失超过50%.xlsx'

# %% [markdown]
# ## 删除分类极不平衡的特征

# %%
# 保护目标变量、tdm数据
for i in df_model.columns[2:]:
    if df_model[i].nunique() < 2:
        del df_model[i]
        continue
    if df_model[i].nunique() == 2:
        # 如果分类变量中某一变量的占比超过90%，则删除该指标
        num_1 = df_model[i].value_counts()  # df一列中不同变量的数目
        num_2 = num_1.div(df_model.shape[0])  # div除法，所有元素都除以相同数值
        num_3 = num_2.max()  # 取出最大值
        if num_3 >= 0.9:
            print(i)
            del df_model[i]
# Out:
# 急性冠脉综合征
# 肾功能不全
# 尿毒症
# 脓毒血症
# 肺水肿
# 肺气肿
# 呼吸衰竭
# 胸腔积液
# 尿路感染
# 腹膜透析
# 肝功能不全
# 高脂血症
# 冠状动脉粥样硬化
# 慢性支气管炎
# 胆囊结石
# 早搏
# 急性肾损伤
# 伐他汀钙
# 谷胱甘肽
# 纤溶酶针
# 丹参多酚酸盐
# 替米沙坦
# 左氧氟沙星
# 氨溴索针
# 阿伐他汀
# 腺苷钴胺
# 多索茶碱
# 醒脑静针

# %%
df_model.shape
# Out:
# (737, 22)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/feature_engineering/df_1.4_删除分类极不平衡.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# ## 过滤异常值

# %%
# 过滤异常值，大于正常值超过100倍！
for i in df_model.columns[2:]:
    # 测试特征是否存在异常值
    median_value= max(df_model[i].median(),1)
    max_value = df_model[i].max()
    if max_value > 100 * median_value:
        print(i)
    df_model[i]=df_model[i].apply(lambda x: np.nan if x<0 or x!=x else 100*median_value if float(x) > 100*median_value else x)
# Out:
# 尿蛋白（PRO）_入院

# %%
df_model.shape
# Out:
# (737, 22)

# %%
# 保存特征清洗
writer = pd.ExcelWriter(project_path + '/data/feature_engineering/df_1_特征清洗.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# # 逐步向前

# %% [markdown]
# ## 插补数据

# %%
# 使用随机森林对缺失值进行插补
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
def missing_value_interpolation(df):
    df = df.reset_index(drop=True)
    # 提取存在缺失值的列名
    missing_list = []
    for i in df.columns:
        if df[i].isnull().sum() > 0:
            missing_list.append(i)
    missing_list_copy = missing_list.copy()
    # 用该列未缺失的值训练随机森林，然后用训练好的rf预测缺失值
    for i in range(len(missing_list)):
        name=missing_list[0]
        df_missing = df[missing_list_copy]
        # 将其他列的缺失值用0表示。
        missing_list.remove(name)
        for j in missing_list:
            df_missing[j]=df_missing[j].astype('str').apply(lambda x: 0 if x=='nan' else x)
        df_missing_is = df_missing[df_missing[name].isnull()]
        df_missing_not = df_missing[df_missing[name].notnull()]
        y = df_missing_not[name]
        x = df_missing_not.drop([name],axis=1)
        # 列出参数列表
        tree_grid_parameter = {'n_estimators': list((10, 50, 100, 150, 200))}
        # 进行参数的搜索组合
        grid = GridSearchCV(RandomForestRegressor(),param_grid=tree_grid_parameter,cv=3)
        #rfr=RandomForestRegressor(random_state=0,n_estimators=100,n_jobs=-1)
        #根据已有数据去拟合随机森林模型
        grid.fit(x, y)
        rfr = RandomForestRegressor(n_estimators=grid.best_params_['n_estimators'])
        rfr.fit(x, y)
        #预测缺失值
        predict = rfr.predict(df_missing_is.drop([name],axis=1))
        #填补缺失值
        df.loc[df[name].isnull(),name] = predict
    return df

# %%
df_model_cb=missing_value_interpolation(df_model)

# %%
df_model_cb.shape
# Out:
# (737, 22)

# %% [markdown]
# ## 划分数据集和过采样

# %%
from sklearn.model_selection import train_test_split
# 划分训练集和测试集，比例为8:2
x = df_model_cb.drop(['class'],axis=1)
y = df_model_cb['class']

tran_x, test_x, tran_y, test_y = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
tran_x.shape
# Out:
# (589, 21)

# %%
tran_y
# Out:
# 546    0
# 141    0
# 489    0
# 21     0
# 674    1
#       ..
# 73     0
# 400    0
# 118    0
# 701    0
# 206    0
# Name: class, Length: 589, dtype: int64

# %%
# 进行过采样
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=0)

tran_x_sm,tran_y_sm = sm.fit_resample(tran_x,tran_y)

# %%
tran_x_sm.shape
# Out:
# (1068, 21)

# %% [markdown]
# ## stepwise forward

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.ensemble import RandomForestClassifier

r2_max_list=[]
feature_max_list=[]
for i in range(1,tran_x_sm.shape[1]+1):
    # 津源xgboost模型
    sfs = SFS(RandomForestClassifier(n_estimators=500,
                                    criterion='entropy',
                                    max_depth=5,
                                    n_jobs=-1,
                                    random_state=3),
              n_jobs=-1, # 并行使用的进程数，默认1个，如果设置为-1，该值为总的核数
              k_features=i,
             forward=True,
             floating=False,  
             verbose=2,  # 显示输出的一些参数，默认为0不输出
             scoring='f1',  # 'f1' for binary targets
             cv=3)  # cv交叉验证

    sfs = sfs.fit(tran_x_sm, tran_y_sm)
    # 逐步向前筛选结果，包括特征个数，最优特征组合及其r2
    sfs_result = sfs.subsets_
    df_sfs = pd.DataFrame(sfs_result)
    # 逐步向前结果
    r2_list=list(df_sfs.loc['avg_score'])
    feature_list=list(df_sfs.loc['feature_names'])
    # 保存特征组合
    r2_max_list.append(r2_list[-1])
    feature_max_list.append(feature_list[-1])
#     if i==4:
#         break
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   14.4s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   15.3s finished
#
# [2021-12-20 10:56:32] Features: 1/1 -- score: 0.7560822622034924[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   12.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   13.3s finished
#
# [2021-12-20 10:56:45] Features: 1/2 -- score: 0.7560822622034924[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    9.6s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   12.5s finished
#
# [2021-12-20 10:56:58] Features: 2/2 -- score: 0.793310317967168[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   11.9s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   12.4s finished
#
# [2021-12-20 10:57:10] Features: 1/3 -- score: 0.7560822622034924[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:   10.5s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   13.3s finished
#
# [2021-12-20 10:57:24] Features: 2/3 -- score: 0.793310317967168[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:   10.2s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   12.9s finished
#
# [2021-12-20 10:57:37] Features: 3/3 -- score: 0.8020892172694829[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   12.0s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   13.0s finished
#
# [2021-12-20 10:57:50] Features: 1/4 -- score: 0.7560822622034924[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    9.8s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:   12.8s finished
#
# [2021-12-20 10:58:03] Features: 2/4 -- score: 0.793310317967168[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    9.3s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   12.1s finished
#
# [2021-12-20 10:58:15] Features: 3/4 -- score: 0.8020892172694829[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:    9.6s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   11.9s finished
#
# [2021-12-20 10:58:27] Features: 4/4 -- score: 0.8379346237668837[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:   12.1s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:   12.5s finished
#
# [2021-12-20 10:58:39] Features: 1/5 -- score: 0.7560822622034924[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:
remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   10.3s finished
#
# [2021-12-20 11:33:15] Features: 7/21 -- score: 0.8644696712534387[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    5.6s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    9.6s finished
#
# [2021-12-20 11:33:25] Features: 8/21 -- score: 0.8650111214302205[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    4.7s remaining:    7.6s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    9.2s finished
#
# [2021-12-20 11:33:34] Features: 9/21 -- score: 0.8633266899233801[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    4.6s remaining:    9.3s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    8.3s finished
#
# [2021-12-20 11:33:42] Features: 10/21 -- score: 0.865194370642425[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    4.5s remaining:   20.4s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    5.6s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    8.0s finished
#
# [2021-12-20 11:33:50] Features: 11/21 -- score: 0.8669395713405054[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    5.6s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    7.9s finished
#
# [2021-12-20 11:33:58] Features: 12/21 -- score: 0.8711102879509918[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    4.4s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    7.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    7.2s finished
#
# [2021-12-20 11:34:06] Features: 13/21 -- score: 0.8700976521898145[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    4.3s remaining:    7.3s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.2s finished
#
# [2021-12-20 11:34:11] Features: 14/21 -- score: 0.8760316834683266[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    4.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    4.6s finished
#
# [2021-12-20 11:34:16] Features: 15/21 -- score: 0.8700442354611712[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    4.0s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    4.1s finished
#
# [2021-12-20 11:34:20] Features: 16/21 -- score: 0.8696294989296783[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.5s remaining:    5.4s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.6s finished
#
# [2021-12-20 11:34:24] Features: 17/21 -- score: 0.8701999261366016[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.4s finished
#
# [2021-12-20 11:34:27] Features: 18/21 -- score: 0.8594630142193447[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
#
# [2021-12-20 11:34:30] Features: 19/21 -- score: 0.8522028990434743[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.7s finished
#
# [2021-12-20 11:34:33] Features: 20/21 -- score: 0.8673195710104006[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    2.5s finished
#
# [2021-12-20 11:34:35] Features: 21/21 -- score: 0.8473819260494705

# %%
df_forward_result=pd.DataFrame(data={'r2':r2_max_list,
                                    'feature_names':feature_max_list})

# %%
# 保存模型测试和测试结果到本地文件
writer = pd.ExcelWriter(project_path + '/data/feature_engineering/df_4_逐步向前特征测试结果.xlsx')
df_forward_result.to_excel(writer)
writer.save()

# %% [markdown]
# ## 逐步向钱画图

# %%
df_forward_result =pd.read_excel(project_path +'/data/feature_engineering/df_4_逐步向前特征测试结果.xlsx')
if 'Unnamed: 0' in df_forward_result.columns:
    df_forward_result = df_forward_result.drop(['Unnamed: 0'], axis=1)

# %%
# 计算R2和MSE、RMSE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score,roc_auc_score,f1_score
# XGBoost模型
feature_col_list=[]
f1_list=[]
for i in range(df_forward_result.shape[0]):
    feature_list=str(df_forward_result.loc[i,'feature_names']).split('\'')
    feature_list=feature_list[1:-1:2]

    tran_x_select=tran_x_sm[feature_list]
    test_x_select=test_x[feature_list]
    # 列出参数列表
    tree_grid_parameter = {'n_estimators': list((10, 50, 100, 150, 200))}
    # 进行参数的搜索组合
    grid = GridSearchCV(RandomForestClassifier(),param_grid=tree_grid_parameter,cv=3)
    #rfr=RandomForestRegressor(random_state=0,n_estimators=100,n_jobs=-1)
    #根据已有数据去拟合随机森林模型
    grid.fit(tran_x_select, tran_y_sm)
    rfr = RandomForestClassifier(n_estimators=grid.best_params_['n_estimators'])
    rfr.fit(tran_x_select, tran_y_sm)
    predictions=rfr.predict(test_x_select)

    # 检验指标
    f1 = roc_auc_score(test_y,predictions)
    feature_col_list.append(feature_list)
    f1_list.append(f1)
    print('f1: ',f1)
# Out:
# f1:  0.480277185501066
# f1:  0.5063965884861407
# f1:  0.5421108742004264
# f1:  0.5458422174840085
# f1:  0.5250533049040511
# f1:  0.5437100213219616
# f1:  0.5437100213219616
# f1:  0.5229211087420043
# f1:  0.5303837953091685
# f1:  0.5474413646055436
# f1:  0.5117270788912579
# f1:  0.5266524520255863
# f1:  0.458955223880597
# f1:  0.4984008528784648
# f1:  0.458955223880597
# f1:  0.5303837953091685
# f1:  0.5021321961620469
# f1:  0.4946695095948827
# f1:  0.5341151385927505
# f1:  0.5378464818763327
# f1:  0.5378464818763327

# %%
df_f1=pd.DataFrame(data={'feature_list':feature_col_list,
                        'f1':f1_list})
df_f1.to_excel(project_path+'/data/feature_engineering/df_f1_画图.xlsx')

# %%
# 画图
# 如果模型画图不好，可以选择在excel中画图
import matplotlib.pyplot as plt
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['SimHei']  ##绘图显示中文
mpl.rcParams['axes.unicode_minus'] = False

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import rc
rc('mathtext', default='regular')

# r2折线图
# 分辨率参数-dpi，画布大小参数-figsize
plt.figure(figsize=(30,10))
plt.plot(list(range(len(f1_list))),f1_list,
         color=(0.32941176470588235, 0.7294117647058823, 0.7490196078431373), label='AUC',linewidth=3) # 线粗细
# 设置坐标刻度值的大小
plt.tick_params(labelsize=23)

# 设置横纵坐标的名称以及对应字体格式
font_x = {'family': 'Times New Roman',
         'weight': 'normal',
         'size': 30,
         }
plt.xlabel('Number of Ranked features',font_x)
plt.ylabel('AUC',font_x)

# 展示横坐标
# x_list=list(df_feature['特征'])
# plt.xticks(list(range(len(f1_list))),f1_list,rotation=285)
# plt.legend(bbox_to_anchor=(1.1,1))  # 显示图例
# Out:
# Text(0, 0.5, 'AUC')

# %% [markdown]
# ## 保存逐步向前筛选的建模数据

# %%
f1_max_index=f1_list.index(max(f1_list))
print(f1_max_index)
feature_com_best=df_forward_result.loc[f1_max_index,'feature_names']
print(feature_com_best)
# Out:
# 9
# ('年龄', '性别', '糖尿病', '心功能不全', '房颤', '血小板_入院', '总胆红素（TBil）_入院', '直接胆红素（DBil）_入院', '尿素氮（BUN）_入院', '尿蛋白（PRO）_入院')

# %%
feature_list=str(feature_com_best).split('\'')
feature_forward_select=feature_list[1:-1:2]
# feature_forward_select=['单核细胞绝对值','异甘草酸镁','甘草酸苷','托烷司琼','谷胱甘肽','红细胞','嗜酸性细胞百分比','多烯磷脂酰',
#                         '嗜碱性细胞百分比','gender','RBC平均容量','MTX_tdm_72h','白蛋白(干式)','中性细胞百分比','MTX_tdm_48h',
#                         '长春新碱','RBC血红浓度']
feature_forward_select.insert(0,'class')

# %%
feature_forward_select
# Out:
# ['class',
#  '年龄',
#  '性别',
#  '糖尿病',
#  '心功能不全',
#  '房颤',
#  '血小板_入院',
#  '总胆红素（TBil）_入院',
#  '直接胆红素（DBil）_入院',
#  '尿素氮（BUN）_入院',
#  '尿蛋白（PRO）_入院']

# %%
df_model_forward=df_model[feature_forward_select]
df_model_forward.to_excel(project_path+'/data/df_model_data_forward.xlsx')
