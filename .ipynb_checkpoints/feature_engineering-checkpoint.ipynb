# %%
# _*_ coding: utf-8 _*_
# @Time: 2021/12/09 16:05 
# @Author: yuyongsheng
# @Software: PyCharm
# @Description: 新华医院生脉注射液：1. 逐步向前 2. 建模

# %%
# 导入程序包
import pymysql as MySQLDB
import pandas as pd
import numpy as np

import re
import sys
import os
project_path = os.getcwd()

# %%
# 字符串转换为时间格式
import datetime
def str_to_datetime(x):
    try:
        a = datetime.datetime.strptime(x, "%d/%m/%Y %H:%M:%S")
        return a
    except:
        return np.NaN

# %% [markdown]
# # 数据清洗

# %%
df_model=pd.read_excel(project_path+'/data/processed_data/df_1.10.6_人工删除不重要列.xlsx')
if 'Unnamed: 0' in df_model.columns:
    df_model = df_model.drop(['Unnamed: 0'], axis=1)

# %%
df_model.rename(columns={'主要疾病转归_描述':'label'},inplace=True)

# %%
print(df_model.shape)
# Out:
# (298, 112)

# %% [markdown]
# ## 删除无关特征

# %%
df_model.columns
# Out:
# Index(['受试者编号', '出院诊断', 'label', '用药开始时间', '用药结束时间', '用药天数', 'EXDOSFRQ',
#        'EXDSTXT', '日剂量', '心血管疾病_label',
#        ...
#        'NSE_入院', 'TPSA_入院', 'AFP_出院', 'CA-125_出院', 'CA-153_出院', 'CA-199_出院',
#        'CA-242_出院', 'CA-50_出院', 'CA-724_出院', 'CEA_出院'],
#       dtype='object', length=112)

# %%
df_model=df_model.drop(['受试者编号', '出院诊断','用药开始时间', '用药结束时间', 'EXDSTXT','住院日期', '完成日期', '住院时长',
                       '血钠_入院','血钾_入院','血氯_入院'],axis=1)

# %%
df_model
# Out:
#      label  用药天数  EXDOSFRQ  日剂量  心血管疾病_label  呼吸系统疾病_label  神经系统疾病_label  \
# 0        0     9         1   30            1             0             1
# 1        1     6         1   40            1             0             1
# 2        0     8         1   60            1             0             0
# 3        0    13         1   60            1             0             1
# 4        0     8         1   40            1             1             1
# ..     ...   ...       ...  ...          ...           ...           ...
# 293      0     5         1   40            1             1             0
# 294      0     7         1   40            1             0             0
# 295      0    10         1   40            1             0             0
# 296      0     8         1   40            1             0             0
# 297      0     7         1   40            1             0             0
#
#      泌尿系统疾病_label  内分泌和代谢疾病_label  消化系统疾病_label  ...  NSE_入院  TPSA_入院  AFP_出院  \
# 0               0               0             0  ...     NaN      NaN    1.48
# 1               0               0             1  ...     NaN      NaN     NaN
# 2               0               0             0  ...     NaN      NaN     NaN
# 3               0               1             0  ...     NaN      NaN     NaN
# 4               0               1             0  ...   12.43     1.44     NaN
# ..            ...             ...           ...  ...     ...      ...     ...
# 293             0               0             1  ...     NaN      NaN     NaN
# 294             1               0             0  ...     NaN      NaN     NaN
# 295             0               0             0  ...     NaN      NaN     NaN
# 296             0               0             0  ...     NaN      NaN     NaN
# 297             0               0             0  ...     NaN      NaN     NaN
#
#      CA-125_出院  CA-153_出院  CA-199_出院  CA-242_出院  CA-50_出院  CA-724_出院  CEA_出院
# 0          NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 1          NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 2          NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 3          NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 4          NaN        NaN        NaN        NaN       NaN        NaN     NaN
# ..         ...        ...        ...        ...       ...        ...     ...
# 293        NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 294        NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 295        NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 296        NaN        NaN        NaN        NaN       NaN        NaN     NaN
# 297        NaN        NaN        NaN        NaN       NaN        NaN     NaN
#
# [298 rows x 101 columns]

# %%
df_model.shape
# Out:
# (298, 101)

# %%
df_model.columns
# Out:
# Index(['label', '用药天数', 'EXDOSFRQ', '日剂量', '心血管疾病_label', '呼吸系统疾病_label',
#        '神经系统疾病_label', '泌尿系统疾病_label', '内分泌和代谢疾病_label', '消化系统疾病_label',
#        ...
#        'NSE_入院', 'TPSA_入院', 'AFP_出院', 'CA-125_出院', 'CA-153_出院', 'CA-199_出院',
#        'CA-242_出院', 'CA-50_出院', 'CA-724_出院', 'CEA_出院'],
#       dtype='object', length=101)

# %%
corr_result=df_model[['label', '用药天数', '日剂量', '呼吸系统疾病_label', '神经系统疾病_label',
       '泌尿系统疾病_label', '内分泌和代谢疾病_label', '年龄', '性别', '基础疾病', 'drug_ASA',
       'drug_AC', '红细胞_入院', '血红蛋白_入院', '白细胞_入院', '中性粒细胞计数_入院', '血小板_入院',
       '红细胞压积_入院', '总胆红素（TBil）_入院', '直接胆红素（DBil）_入院', '白蛋白_入院', '前白蛋白_入院',
       'ALT_入院', 'AST_入院', 'GGT_入院', '尿素氮（BUN）_入院', '肌酐（Cr）_入院','甘油三酯_入院', '胆固醇_入院', 
        '低密度脂蛋白（LDL）_入院','高密度脂蛋白胆固醇（HDLC）_入院', 'PT_入院', 'INR_入院', 'APTT_入院', 'CA-125_入院',
       'CA-153_入院', 'CA-199_入院', 'CA-242_入院']].corr()

# %%
corr_result
# Out:
#                        label      用药天数       日剂量  呼吸系统疾病_label  神经系统疾病_label  \
# label               1.000000 -0.045669  0.090853      0.006194     -0.061073
# 用药天数               -0.045669  1.000000 -0.121403      0.140002      0.037457
# 日剂量                 0.090853 -0.121403  1.000000     -0.013961     -0.191670
# 呼吸系统疾病_label        0.006194  0.140002 -0.013961      1.000000     -0.374372
# 神经系统疾病_label       -0.061073  0.037457 -0.191670     -0.374372      1.000000
# 泌尿系统疾病_label        0.095682  0.068674 -0.009762      0.125627     -0.093498
# 内分泌和代谢疾病_label      0.019746  0.141119 -0.015098      0.000832      0.076748
# 年龄                 -0.052993  0.119589 -0.007235      0.244365     -0.132016
# 性别                  0.096458  0.031468  0.014171     -0.044244      0.042372
# 基础疾病               -0.044224  0.047342 -0.255687     -0.309435      0.614901
# drug_ASA           -0.025542 -0.031286 -0.078343     -0.172918      0.260538
# drug_AC             0.008811 -0.049380 -0.018180     -0.120925      0.194794
# 红细胞_入院             -0.012698 -0.064721 -0.001979      0.000860     -0.007532
# 血红蛋白_入院             0.090891 -0.033166  0.099009     -0.231143      0.148003
# 白细胞_入院              0.146907  0.079795 -0.036327      0.115274     -0.176332
# 中性粒细胞计数_入院          0.062617  0.039397  0.048042      0.230553     -0.050432
# 血小板_入院             -0.016402  0.004719  0.085919     -0.064375     -0.019698
# 直接胆红素（DBil）_入院         -0.033771       -0.093060  0.148337  0.030902
# 白蛋白_入院                 -0.236405       -0.023684 -0.394303  0.008760
# 前白蛋白_入院                -0.073263       -0.092132 -0.482824  0.059918
# ALT_入院                  0.202816       -0.083965 -0.011849 -0.016997
# AST_入院                  0.144491       -0.073748  0.041512 -0.004447
# GGT_入院                  0.147036       -0.101567 -0.131341  0.093233
# 尿素氮（BUN）_入院             0.056905       -0.037317  0.096383 -0.055585
# 肌酐（Cr）_入院               0.497924        0.062841  0.063974  0.041290
# 甘油三酯_入院                -0.076987        0.004751 -0.323069  0.031017
# 胆固醇_入院                 -0.102743       -0.036486 -0.173501 -0.111840
# 低密度脂蛋白（LDL）_入院         -0.059587       -0.059327 -0.159663 -0.007199
# 高密度脂蛋白胆固醇（HDLC）_入院     -0.124371       -0.149259  0.023654 -0.303628
# PT_入院                   0.016040       -0.007527  0.075080  0.058342
# INR_入院                  0.031526        0.066159  0.055631  0.058029
# APTT_入院                 0.086820        0.000974  0.003611  0.152969
# CA-125_入院               0.053952       -0.056271  0.181288  0.071698
# CA-153_入院               0.047494        0.011602 -0.001972 -0.087032
# CA-199_入院               0.028134       -0.031480  0.141108  0.037363
# CA-242_入院              -0.041550       -0.154193 -0.154140  0.151815
#
#                         基础疾病  ...    胆固醇_入院  低密度脂蛋白（LDL）_入院  \
# label              -0.044224  ...  0.132422        0.144285
# 用药天数                0.047342  ... -0.083427       -0.054986
# 日剂量                -0.255687  ... -0.028032        0.011128
# 呼吸系统疾病_label       -0.309435  ... -0.118783       -0.110504
# 神经系统疾病_label        0.614901  ...  0.048184        0.113311
# 泌尿系统疾病_label       -0.112543  ... -0.102743       -0.059587
# 内分泌和代谢疾病_label     -0.023423  ... -0.036486       -0.059327
# 年龄                 -0.076116  ... -0.173501       -0.159663
# 性别                  0.003605  ... -0.111840       -0.007199
# 基础疾病                1.000000  ...  0.118788        0.139680
# drug_ASA            0.150905  ...  0.033726        0.068044
# drug_AC             0.060464  ... -0.054402       -0.089965
# 红细胞_入院             -0.018693  ...  0.280581        0.283576
# 血红蛋白_入院             0.125071  ...  0.335424        0.317981
# 白细胞_入院             -0.137421  ...  0.047001        0.092127
# 中性粒细胞计数_入院         -0.073372  ...  0.073048        0.115539
# 血小板_入院             -0.040255  ...  0.140199        0.177834
# 红细胞压积_入院            0.162217  ...  0.296743        0.282450
# 总胆红素（TBil）_入院      -0.046365  ...  0.022318        0.113718
# 直接胆红素（DBil）_入院     -0.025312  ... -0.223585       -0.139502
# 白蛋白_入院              0.175794  ...  0.321631        0.254359
# 前白蛋白_入院             0.206597  ...  0.340008        0.268006
# ALT_入院             -0.123703  ...  0.011941        0.041586
# AST_入院             -0.134598  ...  0.077339        0.300754
# GGT_入院             -0.201081  ...  0.247949        0.152715
# 尿素氮（BUN）_入院        -0.070989  ... -0.002781       -0.007267
# 肌酐（Cr）_入院          -0.122472  ... -0.006234       -0.017555
# 甘油三酯_入院             0.102952  ...  0.530890        0.290518
# 胆固醇_入院              0.118788  ...  1.000000        0.927186
# 低密度脂蛋白（LDL）_入院      0.139680  ...  0.927186        1.000000
# 高密度脂蛋白胆固醇（HDLC）_入院  0.136833  ...  0.383655        0.226544
# PT_入院              -0.164458  ... -0.271839       -0.235495
# INR_入院             -0.152720  ... -0.256796       -0.210519
# APTT_入院            -0.102659  ... -0.094956       -0.036539
# CA-125_入院          -0.265410  ... -0.181196       -0.161601
# CA-153_入院           0.030266  ...  0.058249        0.038596
# CA-199_入院          -0.025933  ... -0.054038       -0.141924
# CA-242_入院          -0.016262  ...  0.110350        0.056435
#
#                     高密度脂蛋白胆固醇（HDLC）_入院     PT_入院    INR_入院   APTT_入院  \
# label                         0.091759  0.136313  0.144425  0.144841
# 用药天数                         -0.132166 -0.004920 -0.038623 -0.077747
# 日剂量                           0.012193  0.051111 -0.054898  0.079543
# 呼吸系统疾病_label                 -0.038812  0.160488  0.172435 -0.000167
# 神经系统疾病_label                  0.035683 -0.083419 -0.062826 -0.066451
# 泌尿系统疾病_label                 -0.124371  0.016040  0.031526  0.086820
# 内分泌和代谢疾病_label               -0.149259 -0.007527  0.066159  0.000974
# 年龄                            0.023654  0.075080  0.055631  0.003611
# 性别                           -0.303628  0.058342  0.058029  0.152969
# 基础疾病                          0.136833 -0.164458 -0.152720 -0.102659
# drug_ASA                     -0.078319 -0.142885 -0.142962 -0.125781
# drug_AC                       0.001324 -0.123629 -0.127194 -0.024709
# 红细胞_入院                        0.146979  0.015562  0.021066  0.008740
# 血红蛋白_入院                       0.138045  0.002144 -0.032564  0.073207
# 白细胞_入院                       -0.155171  0.098687  0.140438  0.125948
# 中性粒细胞计数_入院                    0.025063  0.045707  0.100556  0.021275
# 血小板_入院                        0.036050 -0.160457 -0.136007 -0.104079
# 红细胞压积_入院                      0.124380  0.005104 -0.037657  0.078674
# 总胆红素（TBil）_入院                 0.015229  0.324856  0.286459  0.183145
# 直接胆红素（DBil）_入院               -0.120067  0.490353  0.372022  0.176513
# 白蛋白_入院                        0.271088 -0.182518 -0.156514 -0.072968
# 前白蛋白_入院                       0.107571 -0.245924 -0.235962 -0.041933
# ALT_入院                        0.066322  0.140851  0.164724  0.021918
# AST_入院                        0.092803  0.128239  0.139778  0.044655
# GGT_入院                        0.021721  0.035122  0.040432  0.146215
# 尿素氮（BUN）_入院                  -0.127781  0.008819  0.018359 -0.051873
# 肌酐（Cr）_入院                    -0.111784  0.007455  0.010582  0.034475
# 甘油三酯_入院                      -0.204982 -0.185023 -0.190553 -0.074979
# 胆固醇_入院                        0.383655 -0.271839 -0.256796 -0.094956
# 低密度脂蛋白（LDL）_入院                0.226544 -0.235495 -0.210519 -0.036539
# 高密度脂蛋白胆固醇（HDLC）_入院            1.000000 -0.137980 -0.087254 -0.005630
# PT_入院                        -0.137980  1.000000  0.846385  0.426373
# INR_入院                       -0.087254  0.846385  1.000000  0.466564
# APTT_入院                      -0.005630  0.426373  0.466564  1.000000
# CA-125_入院                    -0.195823  0.382042  0.144910  0.101522
# CA-153_入院                     0.015239  0.113335  0.093625 -0.017721
# CA-199_入院                     0.001558  0.050155  0.027629  0.029042
# CA-242_入院                     0.110192  0.105527  0.061949  0.084091
#
#                     CA-125_入院  CA-153_入院  CA-199_入院  CA-242_入院
# label                0.117079   0.218328   0.052049   0.072022
# 用药天数                 0.098009  -0.076351  -0.018647  -0.051876
# 日剂量                  0.093541  -0.096618   0.114762  -0.021351
# 呼吸系统疾病_label         0.293803  -0.032254  -0.052553  -0.019970
# 神经系统疾病_label        -0.323321   0.046324  -0.120382   0.015006
# 泌尿系统疾病_label         0.053952   0.047494   0.028134  -0.041550
# 内分泌和代谢疾病_label      -0.056271   0.011602  -0.031480  -0.154193
# 年龄                   0.181288  -0.001972   0.141108  -0.154140
# 性别                   0.071698  -0.087032   0.037363   0.151815
# 基础疾病                -0.265410   0.030266  -0.025933  -0.016262
# drug_ASA            -0.178103   0.019452  -0.051559   0.017290
# drug_AC             -0.135907  -0.112241  -0.068489  -0.010930
# 红细胞_入院               0.131982  -0.006067  -0.063002   0.001295
# 血红蛋白_入院             -0.030338  -0.036761  -0.041214   0.158759
# 白细胞_入院              -0.020033   0.028608  -0.085847  -0.036128
# 中性粒细胞计数_入院           0.115714  -0.024571   0.062013  -0.019553
# 血小板_入院               0.010752   0.022471  -0.050377  -0.088672
# 红细胞压积_入院            -0.067387  -0.060913  -0.038043   0.178070
# 总胆红素（TBil）_入院        0.201084   0.043353  -0.056955   0.007957
# 直接胆红素（DBil）_入院       0.186849   0.100542  -0.040850   0.034095
# 白蛋白_入院              -0.199606  -0.068912  -0.102879   0.110279
# 前白蛋白_入院             -0.336605  -0.066063  -0.058705   0.180442
# ALT_入院               0.214796   0.073478  -0.001410   0.076517
# AST_入院               0.179131   0.071924   0.007800   0.062890
# GGT_入院               0.080722   0.102453   0.000744   0.167565
# 尿素氮（BUN）_入院          0.027820  -0.016234  -0.019122  -0.059491
# 肌酐（Cr）_入院            0.098676   0.063911   0.083651   0.025723
# 甘油三酯_入院             -0.160370   0.141192   0.030633   0.126807
# 胆固醇_入院              -0.181196   0.058249  -0.054038   0.110350
# 低密度脂蛋白（LDL）_入院      -0.161601   0.038596  -0.141924   0.056435
# 高密度脂蛋白胆固醇（HDLC）_入院  -0.195823   0.015239   0.001558   0.110192
# PT_入院                0.382042   0.113335   0.050155   0.105527
# INR_入院               0.144910   0.093625   0.027629   0.061949
# APTT_入院              0.101522  -0.017721   0.029042   0.084091
# CA-125_入院            1.000000   0.088149  -0.000438   0.065133
# CA-153_入院            0.088149   1.000000   0.107425   0.102317
# CA-199_入院           -0.000438   0.107425   1.000000   0.707418
# CA-242_入院            0.065133   0.102317   0.707418   1.000000
#
# [38 rows x 38 columns]

# %%
corr_result[corr_result>0.5].to_excel(project_path+'/data/result/feature_engineering/corr.xlsx')

# %% [markdown]
# ## 删除缺失超过50%的特征

# %% [markdown]
# ### 删除列缺失超过50%的列

# %%
for i in df_model.columns:
    if df_model[i].isnull().sum()/df_model.shape[0] >= 0.5:
        print(i)
        del df_model[i]
# Out:
# 红细胞_出院
# 血红蛋白_出院
# 白细胞_出院
# 中性粒细胞计数_出院
# 血小板_出院
# 红细胞压积_出院
# 尿白细胞（LEU）_入院
# 尿红细胞（ERY）_入院
# 尿蛋白（PRO）_出院
# 尿白细胞（LEU）_出院
# 尿红细胞（ERY）_出院
# AKP_入院
# HCY_入院
# NT-pro BNP_入院
# 肌钙蛋白_入院
# CK-MB_入院
# 总胆红素（TBil）_出院
# 直接胆红素（DBil）_出院
# 白蛋白_出院
# 前白蛋白_出院
# ALT_出院
# AST_出院
# GGT_出院
# AKP_出院
# 尿素氮（BUN）_出院
# 肌酐（Cr）_出院
# 血钠_出院
# 血钾_出院
# 血氯_出院
# 甘油三酯_出院
# 胆固醇_出院
# 低密度脂蛋白（LDL）_出院
# 高密度脂蛋白胆固醇（HDLC）_出院
# HCY_出院
# NT-pro BNP_出院
# 肌钙蛋白_出院
# CK-MB_出院
# PT_出院
# INR_出院
# APTT_出院
# AFP_入院
# CA-50_入院
# CA-724_入院
# CEA_入院
# Cyfra211_入院
# FPSA_入院
# NSE_入院
# TPSA_入院
# AFP_出院
# CA-125_出院
# CA-153_出院
# CA-199_出院
# CA-242_出院
# CA-50_出院
# CA-724_出院
# CEA_出院

# %%
print(df_model.shape)  # (106,101)
# Out:
# (298, 45)

# %% [markdown]
# ### 删除行缺失超过50%的行

# %%
df_model=df_model.reset_index(drop=True)
for i in range(df_model.shape[0]):
    if df_model.loc[i].isnull().sum()/df_model.loc[i].shape[0] >= 0.5:
        print(i)
        df_model.drop([i],axis=0,inplace=True)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/result/feature_engineering/df_1.3_删除缺失超过50%.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# ## 删除分类极不平衡的特征

# %%
# 保护目标变量、tdm数据
for i in df_model.columns[1:]:
    if df_model[i].nunique() < 2:
        del df_model[i]
        continue
    if df_model[i].nunique() == 2:
        # 如果分类变量中某一变量的占比超过90%，则删除该指标
        num_1 = df_model[i].value_counts()  # df一列中不同变量的数目
        num_2 = num_1.div(df_model.shape[0])  # div除法，所有元素都除以相同数值
        num_3 = num_2.max()  # 取出最大值
        if num_3 >= 0.9:
            print(i)
            del df_model[i]
# Out:
# 消化系统疾病_label
# 危重症疾病_label
# family_history
# allergy_history
# drug_crestor

# %%
df_model.shape
# Out:
# (298, 38)

# %%
# 删除缺失超过50%的特征
writer=pd.ExcelWriter(project_path+'/data/result/feature_engineering/df_1.4_删除分类极不平衡.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# ## 过滤异常值

# %%
# 过滤异常值，大于正常值超过100倍！
for i in df_model.columns[2:]:
    # 测试特征是否存在异常值
    median_value= max(df_model[i].median(),1)
    max_value = df_model[i].max()
    if max_value > 100 * median_value:
        print(i)
    df_model[i]=df_model[i].apply(lambda x: np.nan if x<0 or x!=x else 100*median_value if float(x) > 100*median_value else x)

# %%
df_model.shape
# Out:
# (298, 38)

# %%
# 保存特征清洗
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_1_特征清洗.xlsx')
df_model.to_excel(writer)
writer.save()

# %% [markdown]
# # 显著性分析

# %%
df_model.columns
# Out:
# Index(['label', '用药天数', '日剂量', '呼吸系统疾病_label', '神经系统疾病_label', '泌尿系统疾病_label',
#        '内分泌和代谢疾病_label', '年龄', '性别', '基础疾病', 'drug_ASA', 'drug_AC', '红细胞_入院',
#        '血红蛋白_入院', '白细胞_入院', '中性粒细胞计数_入院', '血小板_入院', '红细胞压积_入院',
#        '总胆红素（TBil）_入院', '直接胆红素（DBil）_入院', '白蛋白_入院', '前白蛋白_入院', 'ALT_入院',
#        'AST_入院', 'GGT_入院', '尿素氮（BUN）_入院', '肌酐（Cr）_入院', '甘油三酯_入院', '胆固醇_入院',
#        '低密度脂蛋白（LDL）_入院', '高密度脂蛋白胆固醇（HDLC）_入院', 'PT_入院', 'INR_入院', 'APTT_入院',
#        'CA-125_入院', 'CA-153_入院', 'CA-199_入院', 'CA-242_入院'],
#       dtype='object')

# %%
discrete_col=['呼吸系统疾病_label', '神经系统疾病_label', '泌尿系统疾病_label','内分泌和代谢疾病_label','性别', '基础疾病',
              'drug_ASA', 'drug_AC']
continuous_col=[x for x in df_model.columns if x not in discrete_col]
continuous_col.remove('label')

# %% [markdown]
# ## 分类变量显著性分析

# %%
# 二分类卡方检验
from scipy.stats import chi2_contingency
feature_list=[]
y_list=[]
t_list=[]
p_list=[]
sig_list=[]
for i in discrete_col:
    print(i)
    result = chi2_contingency(pd.crosstab(df_model['label'],df_model[i]))
    t,p=result[0:2]
    t=round(t,2)
    p=round(p,3)
    feature_list.append(i)
    y_list.append('卡方检验')
    t_list.append(t)
    p_list.append(p)
    if p <=0.05:
        sig='显著'
    else:
        sig='不显著'
    sig_list.append(sig)
# Out:
# 呼吸系统疾病_label
# 神经系统疾病_label
# 泌尿系统疾病_label
# 内分泌和代谢疾病_label
# 性别
# 基础疾病
# drug_ASA
# drug_AC

# %%
df_discrete_sig=pd.DataFrame({'feature':feature_list,
                        '检验指标':y_list,
                        't值':t_list,
                        'p值':p_list,
                        'result':sig_list})

# %%
# 分类变量显著性检验
df_discrete_sig.to_excel(project_path+'/data/result/feature_engineering/df_2.1_分类变量显著性检验.xlsx')

# %%
df_discrete_sig
# Out:
#           feature  检验指标    t值     p值 result
# 0    呼吸系统疾病_label  卡方检验  0.01  0.934    不显著
# 1    神经系统疾病_label  卡方检验  0.77  0.381    不显著
# 2    泌尿系统疾病_label  卡方检验  1.93  0.164    不显著
# 3  内分泌和代谢疾病_label  卡方检验  0.02  0.882    不显著
# 4              性别  卡方检验  2.21  0.137    不显著
# 5            基础疾病  卡方检验  0.32  0.573    不显著
# 6        drug_ASA  卡方检验  0.04  0.841    不显著
# 7         drug_AC  卡方检验  0.01  0.911    不显著

# %%
discrete_relate=list(df_discrete_sig[df_discrete_sig.result=='显著']['feature'])

# %%
discrete_relate
# Out:
# []

# %%
list(df_discrete_sig[df_discrete_sig.result=='不显著']['feature'])
# Out:
# ['呼吸系统疾病_label',
#  '神经系统疾病_label',
#  '泌尿系统疾病_label',
#  '内分泌和代谢疾病_label',
#  '性别',
#  '基础疾病',
#  'drug_ASA',
#  'drug_AC']

# %%
# 保留业务需要的不显著变量
discrete_relate.extend(['呼吸系统疾病_label','神经系统疾病_label','泌尿系统疾病_label','内分泌和代谢疾病_label','性别','基础疾病',
                       'drug_ASA', 'drug_AC'])

# %% [markdown]
# ## 连续变量显著性分析

# %%
from scipy.stats import kstest,shapiro
##检验是否正态
def norm_test(data):
    if len(data) > 30:
        norm, p = kstest(data, 'norm')
    else:
        norm, p = shapiro(data)
    #print(t,p)
    if p>=0.05:
        return True
    else:
        return False

# %%
import scipy.stats as st
# 连续变量的显著性检验
def test2(data_b, data_p):
    if norm_test(data_b) and norm_test(data_p):
        x = 1
        y = '独立样本T检验'
        t, p = st.ttest_ind(list(data_b),list(data_p), nan_policy='omit')
    else:
        x = 0
        y = 'Mann-Whitney U检验'
        t,p = st.mannwhitneyu(list(data_b),list(data_p))
    return x,y,t,p

# %%
def sig_test(df_high,df_low,list1):

    feature_list=[]  # 特征列表
    y_list=[]  # 显著性检验方法
    t_list=[]  # 统计量
    p_list=[]  # p值
    result_list=[]  # 是否显著
    high_mean_list=[]
    low_mean_list=[]

    for i in list1:
        print(i)
        # 高剂量组统计
        df_high_nt=df_high[df_high[i].notnull()]
        data_high=df_high_nt[i]
        high_mean=round(data_high.mean(),2)
        
        df_low_nt=df_low[df_low[i].notnull()]
        data_low=df_low_nt[i]
        low_mean=round(data_low.mean(),2)

        # 计算高低剂量组显著性差异
        if data_high.shape[0] >= 10 and data_low.shape[0]>=10:
            # 连续变量检验
            x,y,t,p = test2(data_high, data_low)
            t=round(t,2)
            p=round(p,3)
            if p <=0.05:
                sig='显著'
            else:
                sig='不显著'
            # 显著性 
            feature_list.append(i)
            y_list.append(y)
            t_list.append(t)
            p_list.append(p)
            result_list.append(sig)
            high_mean_list.append(high_mean)
            low_mean_list.append(low_mean)

    df_result=pd.DataFrame({'特征':feature_list,
                            '高剂量均值':high_mean_list,
                            '低剂量均值':low_mean_list,
                            '检验指标':y_list,
                            't值':t_list,
                            'p值':p_list,
                            '显著性结果':result_list})
    return df_result

# %%
# 提取甲氨蝶呤不同标签
df_MTX_high = df_model[df_model['label']==1]
df_MTX_low = df_model[df_model['label']==0]

# %%
# 甲氨蝶呤高低剂量组PSM控制变量统计和显著性检验
df_MTX_PSM_sig = sig_test(df_MTX_high,df_MTX_low,continuous_col)
df_MTX_PSM_sig = df_MTX_PSM_sig.reset_index(drop=True)
# Out:
# 用药天数
# 日剂量
# 年龄
# 红细胞_入院
# 血红蛋白_入院
# 白细胞_入院
# 中性粒细胞计数_入院
# 血小板_入院
# 红细胞压积_入院
# 总胆红素（TBil）_入院
# 直接胆红素（DBil）_入院
# 白蛋白_入院
# 前白蛋白_入院
# ALT_入院
# AST_入院
# GGT_入院
# 尿素氮（BUN）_入院
# 肌酐（Cr）_入院
# 甘油三酯_入院
# 胆固醇_入院
# 低密度脂蛋白（LDL）_入院
# 高密度脂蛋白胆固醇（HDLC）_入院
# PT_入院
# INR_入院
# APTT_入院
# CA-125_入院
# CA-153_入院
# CA-199_入院
# CA-242_入院

# %%
# 保存高低剂量组PSM控制变量统计和显著性检验
writer=pd.ExcelWriter(project_path+r'/data/result/feature_engineering/df_2.2_连续变量相关性分析.xlsx')
df_MTX_PSM_sig.to_excel(writer)
writer.save()

# %%
df_MTX_PSM_sig
# Out:
#                     特征   高剂量均值   低剂量均值              检验指标      t值     p值 显著性结果
# 0                 用药天数    7.67    8.55  Mann-Whitney U检验  3654.0  0.014    显著
# 1                  日剂量   44.17   41.41  Mann-Whitney U检验  4408.0  0.232   不显著
# 2                   年龄   70.14   72.40  Mann-Whitney U检验  4139.5  0.117   不显著
# 3               红细胞_入院    4.14    4.23  Mann-Whitney U检验  3929.5  0.086   不显著
# 4              血红蛋白_入院  127.03  121.18  Mann-Whitney U检验  3769.5  0.044    显著
# 5               白细胞_入院    9.81    8.00  Mann-Whitney U检验  2917.0  0.000    显著
# 6           中性粒细胞计数_入院   70.88   66.93  Mann-Whitney U检验  3284.0  0.014    显著
# 7               血小板_入院  191.47  195.15  Mann-Whitney U检验  4447.0  0.425   不显著
# 8             红细胞压积_入院   37.72   35.91  Mann-Whitney U检验  3691.0  0.035    显著
# 9        总胆红素（TBil）_入院   15.63   14.20  Mann-Whitney U检验  2475.0  0.058   不显著
# 10      直接胆红素（DBil）_入院    3.43    3.87  Mann-Whitney U检验  2844.5  0.453   不显著
# 11              白蛋白_入院   36.90   37.31  Mann-Whitney U检验  3880.0  0.223   不显著
# 12             前白蛋白_入院  193.26  194.74  Mann-Whitney U检验  1668.0  0.345   不显著
# 13              ALT_入院   47.00   30.00  Mann-Whitney U检验  1817.0  0.000    显著
# 14              AST_入院   78.05   42.50  Mann-Whitney U检验  1825.5  0.000    显著
# 15              GGT_入院   73.31   35.20  Mann-Whitney U检验  1905.5  0.008    显著
# 16         尿素氮（BUN）_入院    9.54    9.67  Mann-Whitney U检验  3329.5  0.105   不显著
# 17           肌酐（Cr）_入院  149.57   98.15  Mann-Whitney U检验  3304.0  0.094   不显著
# 18             甘油三酯_入院    1.57    1.63  Mann-Whitney U检验  2179.0  0.140   不显著
# 19              胆固醇_入院    4.61    4.08  Mann-Whitney U检验  1746.5  0.045    显著
# 20      低密度脂蛋白（LDL）_入院    2.72    2.34  Mann-Whitney U检验  1753.0  0.095   不显著
# 21  高密度脂蛋白胆固醇（HDLC）_入院    1.37    1.27  Mann-Whitney U检验  2011.5  0.240   不显著
# 22               PT_入院   15.06   13.06  Mann-Whitney U检验  2370.0  0.000    显著
# 23              INR_入院    1.33    1.15  Mann-Whitney U检验  2422.5  0.000    显著
# 24             APTT_入院   33.34   31.02  Mann-Whitney U检验  3383.0  0.047    显著
# 25           CA-125_入院   38.37   23.45  Mann-Whitney U检验   845.5  0.003    显著
# 26           CA-153_入院   16.62   10.93  Mann-Whitney U检验   535.0  0.003    显著
# 27           CA-199_入院   16.66   13.88  Mann-Whitney U检验   998.0  0.027    显著
# 28           CA-242_入院    6.19    5.16  Mann-Whitney U检验   702.5  0.128   不显著

# %%
continuous_relate = list(df_MTX_PSM_sig[df_MTX_PSM_sig['显著性结果']=='显著']['特征'])

# %%
continuous_relate
# Out:
# ['用药天数',
#  '血红蛋白_入院',
#  '白细胞_入院',
#  '中性粒细胞计数_入院',
#  '红细胞压积_入院',
#  'ALT_入院',
#  'AST_入院',
#  'GGT_入院',
#  '胆固醇_入院',
#  'PT_入院',
#  'INR_入院',
#  'APTT_入院',
#  'CA-125_入院',
#  'CA-153_入院',
#  'CA-199_入院']

# %%
list(df_MTX_PSM_sig[df_MTX_PSM_sig['显著性结果']=='不显著']['特征'])
# Out:
# ['日剂量',
#  '年龄',
#  '红细胞_入院',
#  '血小板_入院',
#  '总胆红素（TBil）_入院',
#  '直接胆红素（DBil）_入院',
#  '白蛋白_入院',
#  '前白蛋白_入院',
#  '尿素氮（BUN）_入院',
#  '肌酐（Cr）_入院',
#  '甘油三酯_入院',
#  '低密度脂蛋白（LDL）_入院',
#  '高密度脂蛋白胆固醇（HDLC）_入院',
#  'CA-242_入院']

# %%
# 业务角度需要保留：日剂量、age、MTX_tdm_24h、MTX_tdm_48h、MTX_tdm_72h
continuous_relate.extend(['日剂量','年龄','血小板_入院','甘油三酯_入院','低密度脂蛋白（LDL）_入院','高密度脂蛋白胆固醇（HDLC）_入院'])

# %%
len(continuous_relate)
# Out:
# 21

# %%
# 提取相关性特征
feature_relate=discrete_col + continuous_relate
# 加入目标变量
feature_relate.insert(0,'label')
df_model_relate=df_model[feature_relate]

# %%
df_model_relate.shape
# Out:
# (298, 30)

# %%
# 保存显著性分析结果
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_2_显著性清洗.xlsx')
df_model_relate.to_excel(writer)
writer.save()

# %% [markdown]
# # 重要性评分

# %%
df_model_relate.shape
# Out:
# (298, 30)

# %%
from sklearn.model_selection import train_test_split

# 划分训练集和测试集，比例为8:2
x = df_model_relate.drop(['label'],axis=1)
y = df_model_relate['label']
tran_x, test_x, tran_y, test_y = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
# 重要性
import catboost,xgboost
model_boost=xgboost.XGBClassifier(max_depth=5,
                                learning_rate=0.01,
                                n_estimators=500,
                                min_child_weight=0.5,
                                eta=0.1,
                                gamma=0.5,
                                reg_lambda=10,
                                subsample=0.5,
                                colsample_bytree=0.8,
                                nthread=4,
                                scale_pos_weight=1)
model_boost.fit(tran_x,tran_y)
importance = model_boost.feature_importances_
print(tran_x.columns)
print(importance)
# Out:
# Index(['呼吸系统疾病_label', '神经系统疾病_label', '泌尿系统疾病_label', '内分泌和代谢疾病_label', '性别',
#        '基础疾病', 'drug_ASA', 'drug_AC', '用药天数', '血红蛋白_入院', '白细胞_入院',
#        '中性粒细胞计数_入院', '红细胞压积_入院', 'ALT_入院', 'AST_入院', 'GGT_入院', '胆固醇_入院',
#        'PT_入院', 'INR_入院', 'APTT_入院', 'CA-125_入院', 'CA-153_入院', 'CA-199_入院',
#        '日剂量', '年龄', '血小板_入院', '甘油三酯_入院', '低密度脂蛋白（LDL）_入院',
#        '高密度脂蛋白胆固醇（HDLC）_入院'],
#       dtype='object')
# [0.02921147 0.01937766 0.01879116 0.0168468  0.02495722 0.02331522
#  0.         0.02834389 0.04437968 0.05056515 0.05257289 0.03212452
#  0.0511838  0.05678245 0.04795254 0.03181265 0.03389062 0.03412338
#  0.0371482  0.0584839  0.02736274 0.03606636 0.03114526 0.04487448
#  0.02313774 0.02680791 0.0291416  0.04631928 0.04328145]

# %%
df_importance= pd.DataFrame(data={'特征':tran_x.columns,'重要性评分':importance})
df_importance['重要性评分']=df_importance['重要性评分'].apply(lambda x: round(x,3))
df_importance=df_importance.sort_values(['重要性评分'],ascending=False)
df_importance=df_importance.reset_index(drop=True)

# %%
df_importance.to_excel(project_path + '/data/result/feature_engineering/df_3_模型重要性评分.xlsx')

# %%
# 筛选重要特征组建建模数据
df_importance_select=df_importance[df_importance['重要性评分']>0]
select_list = list(df_importance_select['特征'])
select_list.insert(0,'label')

# %%
df_model_importance = df_model_relate[select_list]

# %%
df_model_importance.shape
# Out:
# (298, 29)

# %%
# 保存重要性评分筛选后的建模数据
writer = pd.ExcelWriter(project_path + '/data/result/feature_engineering/df_model_data_importance.xlsx')
df_model_importance.to_excel(writer)
writer.save()

# %% [markdown]
# # 逐步向前

# %% [markdown]
# ## 插补数据

# %%
# 使用随机森林对缺失值进行插补
import pandas as pd
pd.set_option('mode.chained_assignment', None)
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
def missing_value_interpolation(df):
    df = df.reset_index(drop=True)
    # 提取存在缺失值的列名
    missing_list = []
    for i in df.columns:
        if df[i].isnull().sum() > 0:
            missing_list.append(i)
    missing_list_copy = missing_list.copy()
    # 用该列未缺失的值训练随机森林，然后用训练好的rf预测缺失值
    for i in range(len(missing_list)):
        name=missing_list[0]
        df_missing = df[missing_list_copy]
        # 将其他列的缺失值用0表示。
        missing_list.remove(name)
        for j in missing_list:
            df_missing[j]=df_missing[j].astype('str').apply(lambda x: 0 if x=='nan' else x)
        df_missing_is = df_missing[df_missing[name].isnull()]
        df_missing_not = df_missing[df_missing[name].notnull()]
        y = df_missing_not[name]
        x = df_missing_not.drop([name],axis=1)
        # 列出参数列表
        tree_grid_parameter = {'n_estimators': list((10, 50, 100, 150, 200))}
        # 进行参数的搜索组合
        grid = GridSearchCV(RandomForestRegressor(),param_grid=tree_grid_parameter,cv=3)
        #rfr=RandomForestRegressor(random_state=0,n_estimators=100,n_jobs=-1)
        #根据已有数据去拟合随机森林模型
        grid.fit(x, y)
        rfr = RandomForestRegressor(n_estimators=grid.best_params_['n_estimators'])
        rfr.fit(x, y)
        #预测缺失值
        predict = rfr.predict(df_missing_is.drop([name],axis=1))
        #填补缺失值
        df.loc[df[name].isnull(),name] = predict
    return df

# %%
df_model_relate.shape
# Out:
# (298, 30)

# %%
df_model_cb=missing_value_interpolation(df_model_relate)
# df_model_cb=df_model_importance

# %% [markdown]
# ## 划分数据集和过采样

# %%
from sklearn.model_selection import train_test_split
# 划分训练集和测试集，比例为8:2
x = df_model_cb.drop(['label'],axis=1)
y = df_model_cb['label']

tran_x, test_x, tran_y, test_y = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
tran_x.shape
# Out:
# (238, 29)

# %%
tran_y
# Out:
# 42     0
# 202    0
# 214    0
# 194    0
# 236    0
#       ..
# 8      1
# 73     0
# 118    0
# 189    0
# 206    0
# Name: label, Length: 238, dtype: int64

# %%
# 进行过采样
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=0)

tran_x_sm,tran_y_sm = sm.fit_resample(tran_x,tran_y)

# %%
tran_x_sm.shape
# Out:
# (414, 29)

# %% [markdown]
# ## stepwise forward

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.ensemble import RandomForestClassifier

r2_max_list=[]
feature_max_list=[]
for i in range(1,tran_x_sm.shape[1]+1):
    # 津源xgboost模型
    sfs = SFS(xgboost.XGBClassifier(max_depth=5,
                        learning_rate=0.01,
                        n_estimators=300,
                        min_child_weight=0.5,
                        eta=0.1,
                        gamma=0.5,
                        reg_lambda=10,
                        subsample=0.5,
                        colsample_bytree=0.8,
                        nthread=4,
                        scale_pos_weight=1,
                        random_state=3),
              n_jobs=-1, # 并行使用的进程数，默认1个，如果设置为-1，该值为总的核数
              k_features=i,
             forward=True,
             floating=False,  
             verbose=2,  # 显示输出的一些参数，默认为0不输出
             scoring='accuracy', # for binary targets
             cv=3)  # cv交叉验证

    sfs = sfs.fit(tran_x_sm, tran_y_sm)
    # 逐步向前筛选结果，包括特征个数，最优特征组合及其r2
    sfs_result = sfs.subsets_
    df_sfs = pd.DataFrame(sfs_result)
    # 逐步向前结果
    r2_list=list(df_sfs.loc['avg_score'])
    feature_list=list(df_sfs.loc['feature_names'])
    # 保存特征组合
    r2_max_list.append(r2_list[-1])
    feature_max_list.append(feature_list[-1])
#     if i==4:
#         break
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.9s finished
#
# [2022-03-30 20:29:29] Features: 1/1 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.9s finished
#
# [2022-03-30 20:29:35] Features: 1/2 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.9s finished
#
# [2022-03-30 20:29:41] Features: 2/2 -- score: 0.8502415458937199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    6.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    6.2s finished
#
# [2022-03-30 20:29:47] Features: 1/3 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s finished
#
# [2022-03-30 20:29:53] Features: 2/3 -- score: 0.8502415458937199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.7s finished
#
# [2022-03-30 20:29:59] Features: 3/3 -- score: 0.8647342995169082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s finished
#
# [2022-03-30 20:30:04] Features: 1/4 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s finished
#
# [2022-03-30 20:30:10] Features: 2/4 -- score: 0.8502415458937199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-03-30 20:30:15] Features: 3/4 -- score: 0.8647342995169082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.5s finished
#
# [2022-03-30 20:30:21] Features: 4/4 -- score: 0.8864734299516908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s finished
#
# [2022-03-30 20:30:26] Features: 1/5 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.8s finished
#
# [2022-03-30 20:30:32] Features: 2/5 -- score: 0.8502415458937199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.9s finished
#
# [2022-03-30 20:30:38] Features: 3/5 -- score: 0.8647342995169082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    6.0s finished
#
# [2022-03-30 20:30:44] Features: 4/5 -- score: 0.8864734299516908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.9s finished
#
# [2022-03-30 20:30:50] Features: 5/5 -- score: 0.8816425120772946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.8s finished
#
# [2022-03-30 20:30:56] Features: 1/6 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    6.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    6.5s finished
#
# [2022-03-30 20:31:03] Features: 2/6 -- score: 0.8502415458937199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-03-30 20:31:09] Features: 3/6 -- score: 0.8647342995169082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.6s finished
#
# [2022-03-30 20:31:14] Features: 4/6 -- score: 0.8864734299516908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.6s finished
#
# [2022-03-30 20:31:20] Features: 5/6 -- score: 0.8816425120772946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    5.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    5.1s finished
#
# [2022-03-30 20:31:25] Features: 6/6 -- score: 0.8985507246376812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.7s finished
#
# [2022-03-30 20:31:31] Features: 1/7 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s finished
#
# [2022-03-30 20:31:36] Features: 2/7 -- score: 0.8502415458937199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-03-30 20:31:42] Features: 3/7 -- score: 0.8647342995169082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.7s finished
#
# [2022-03-30 20:31:48] Features: 4/7 -- score: 0.8864734299516908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.5s finished
#
# [2022-03-30 20:31:53] Features: 5/7 -- score: 0.8816425120772946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    5.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    5.2s finished
#
# [2022-03-30 20:31:59] Features: 6/7 -- score: 0.8985507246376812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    5.0s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    5.0s finished
#
# [2022-03-30 20:32:04] Features: 7/7 -- score: 0.9082125603864735[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    5.5s finished
#
# [2022-03-30 20:32:09] Features: 1/8 -- score: 0.7995169082125604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    5.3s finished
#
# [2022-03-30 20:32:15] Features: 2/8 -- score: 0.8502415458937199[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    5.5s finished
#
# [2022-03-30 20:32:20] Features: 3/8 -- score: 0.8647342995169082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.5s finished
#
# [2022-03-30 20:32:26] Features: 4/8 -- score: 0.8864734299516908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.2s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.6s finished
#
# [2022-03-30 20:32:32] Features: 5/8 -- score: 0.8816425120772946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    5.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    5.1s finished
#
# [2022-03-30 20
[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    5.5s finished
#
# [2022-03-30 21:00:53] Features: 4/29 -- score: 0.8864734299516908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  25 | elapsed:    5.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    5.5s finished
#
# [2022-03-30 21:00:59] Features: 5/29 -- score: 0.8816425120772946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  24 | elapsed:    5.1s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    5.1s finished
#
# [2022-03-30 21:01:04] Features: 6/29 -- score: 0.8985507246376812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    5.0s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    5.0s finished
#
# [2022-03-30 21:01:09] Features: 7/29 -- score: 0.9082125603864735[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    4.9s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    4.9s finished
#
# [2022-03-30 21:01:14] Features: 8/29 -- score: 0.8985507246376812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of  21 | elapsed:    4.7s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    4.7s finished
#
# [2022-03-30 21:01:19] Features: 9/29 -- score: 0.9033816425120773[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  20 | elapsed:    3.7s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    4.7s finished
#
# [2022-03-30 21:01:24] Features: 10/29 -- score: 0.9009661835748792[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    3.7s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    4.5s finished
#
# [2022-03-30 21:01:28] Features: 11/29 -- score: 0.8961352657004831[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:    3.8s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:    4.4s finished
#
# [2022-03-30 21:01:33] Features: 12/29 -- score: 0.8961352657004831[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    3.9s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:    4.4s finished
#
# [2022-03-30 21:01:37] Features: 13/29 -- score: 0.8937198067632851[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    3.8s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    3.8s finished
#
# [2022-03-30 21:01:41] Features: 14/29 -- score: 0.8913043478260869[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    2.0s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    3.7s finished
#
# [2022-03-30 21:01:45] Features: 15/29 -- score: 0.8913043478260869[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    2.0s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    3.4s finished
#
# [2022-03-30 21:01:49] Features: 16/29 -- score: 0.888888888888889[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    2.0s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    3.3s finished
#
# [2022-03-30 21:01:52] Features: 17/29 -- score: 0.888888888888889[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    2.2s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    3.2s finished
#
# [2022-03-30 21:01:55] Features: 18/29 -- score: 0.8864734299516908[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    2.0s remaining:    9.6s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    2.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    2.9s finished
#
# [2022-03-30 21:01:58] Features: 19/29 -- score: 0.888888888888889[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    2.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.7s finished
#
# [2022-03-30 21:02:01] Features: 20/29 -- score: 0.8961352657004831[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    2.0s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    2.6s finished
#
# [2022-03-30 21:02:04] Features: 21/29 -- score: 0.9009661835748792[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.0s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.1s finished
#
# [2022-03-30 21:02:06] Features: 22/29 -- score: 0.9033816425120773[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    1.8s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.8s finished
#
# [2022-03-30 21:02:08] Features: 23/29 -- score: 0.8985507246376812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    1.6s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    1.6s finished
#
# [2022-03-30 21:02:10] Features: 24/29 -- score: 0.9009661835748792[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.3s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.3s finished
#
# [2022-03-30 21:02:11] Features: 25/29 -- score: 0.8985507246376812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    1.1s finished
#
# [2022-03-30 21:02:12] Features: 26/29 -- score: 0.9009661835748792[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.8s finished
#
# [2022-03-30 21:02:13] Features: 27/29 -- score: 0.8985507246376812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s finished
#
# [2022-03-30 21:02:14] Features: 28/29 -- score: 0.8913043478260869[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.5s finished
#
# [2022-03-30 21:02:15] Features: 29/29 -- score: 0.8816425120772946

# %%
df_forward_result=pd.DataFrame(data={'auc':r2_max_list,
                                    'feature_names':feature_max_list})

# %%
df_forward_result.shape
# Out:
# (29, 2)

# %%
# 保存模型测试和测试结果到本地文件
df_forward_result.to_excel(project_path + '/data/result/feature_engineering/df_4.3_逐步向前特征测试结果.xlsx')

# %% [markdown]
# ## 逐步向钱画图

# %%
df_forward_result =pd.read_excel(project_path +'/data/result/feature_engineering/df_4.3_逐步向前特征测试结果_.xlsx')
if 'Unnamed: 0' in df_forward_result.columns:
    df_forward_result = df_forward_result.drop(['Unnamed: 0'], axis=1)

# %%
df_forward_result.head()
# Out:
#         auc                                      feature_names
# 0  0.819295                                           ('日剂量',)
# 1  0.846998                                  ('AST_入院', '日剂量')
# 2  0.859638                     ('AST_入院', 'CA-199_入院', '日剂量')
# 3  0.883840             ('用药天数', 'AST_入院', 'CA-199_入院', '日剂量')
# 4  0.895583  ('用药天数', 'AST_入院', 'CA-199_入院', '日剂量', '甘油三酯_入院')

# %%
f1_max_list=list(df_forward_result['auc'])
feature_max_list=list(df_forward_result['feature_names'])

# %%
# 画图
# 如果模型画图不好，可以选择在excel中画图
import matplotlib.pyplot as plt
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['SimHei']  ##绘图显示中文
mpl.rcParams['axes.unicode_minus'] = False

from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
from matplotlib import rc
rc('mathtext', default='regular')


# r2折线图
# 分辨率参数-dpi，画布大小参数-figsize
plt.figure(figsize=(30,10))
plt.plot(list(range(1,len(f1_max_list)+1)),f1_max_list,
         color=(0.32941176470588235, 0.7294117647058823, 0.7490196078431373), label='AUC',linewidth=3) # 线粗细
# 设置坐标刻度值的大小
plt.tick_params(labelsize=23)

# 设置横纵坐标标题的名称以及对应字体格式
font_x = {'family': 'Times New Roman',
         'weight': 'normal',
         'size': 30,}
plt.xlabel('Number of Ranked features',font_x)
plt.ylabel('AUC',font_x)

# 设置横纵坐标刻度范围、间隔、名称
# x_list=list(df_feature['特征'])
plt.xticks(range(1,len(f1_max_list)+1,3))
# plt.yticks(list(range(len(f1_list))),f1_list,rotation=285)
# plt.legend(bbox_to_anchor=(1.1,1))  # 显示图例
# Out:
# ([<matplotlib.axis.XTick at 0x18b523f5550>,
#   <matplotlib.axis.XTick at 0x18b523cddd8>,
#   <matplotlib.axis.XTick at 0x18b523cdeb8>,
#   <matplotlib.axis.XTick at 0x18b54d0ac18>,
#   <matplotlib.axis.XTick at 0x18b54d150f0>,
#   <matplotlib.axis.XTick at 0x18b54d15588>,
#   <matplotlib.axis.XTick at 0x18b54d15a20>,
#   <matplotlib.axis.XTick at 0x18b54d15eb8>,
#   <matplotlib.axis.XTick at 0x18b54d1c390>,
#   <matplotlib.axis.XTick at 0x18b54d1c828>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## 保存逐步向前筛选的建模数据

# %%
f1_max_index=f1_max_list.index(max(f1_max_list))
print(f1_max_index)
feature_com_best=df_forward_result.loc[f1_max_index,'feature_names']
print(feature_com_best)
# Out:
# 13
# ('泌尿系统疾病_label', '基础疾病', 'drug_ASA', '用药天数', 'AST_入院', 'GGT_入院', 'INR_入院', 'APTT_入院', 'CA-199_入院', '日剂量', '年龄', '血小板_入院', '甘油三酯_入院', '高密度脂蛋白胆固醇（HDLC）_入院')

# %%
feature_list=str(feature_com_best).split('\'')
feature_forward_select=feature_list[1:-1:2]
# 查找文献，判断变量是否与目标变量相关
# feature_forward_select.remove('中性粒细胞')
feature_forward_select.insert(0,'label')

# %%
feature_forward_select
# Out:
# ['label',
#  '泌尿系统疾病_label',
#  '基础疾病',
#  'drug_ASA',
#  '用药天数',
#  'AST_入院',
#  'GGT_入院',
#  'INR_入院',
#  'APTT_入院',
#  'CA-199_入院',
#  '日剂量',
#  '年龄',
#  '血小板_入院',
#  '甘油三酯_入院',
#  '高密度脂蛋白胆固醇（HDLC）_入院']

# %%
df_model_forward=df_model[feature_forward_select]
df_model_forward.to_excel(project_path+'/data/result/feature_engineering/df_4.5_model_data_forward.xlsx')
